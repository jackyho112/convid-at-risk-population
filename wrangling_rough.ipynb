# %%
import pandas as pd
import numpy as np 
import altair as alt

alt.data_transformers.enable('json')
# Out:
# DataTransformerRegistry.enable('json')

# %%
def retrieve_appregate_data():
    county_infection_data = pd.read_csv('relevant_data/us-counties.csv')
    county_population_data = pd.read_csv('relevant_data/county-population.csv')
    state_party_line_data = pd.read_csv('relevant_data/state_party_line.csv')
    
    county_infection_popu_data = county_infection_data.merge(
        county_population_data, left_on=['county', 'state'], right_on=['county', 'state']
    ).merge(
        state_party_line_data, left_on=['state'], right_on=['state']
    )
    
    return county_infection_popu_data

# %%
data = retrieve_appregate_data()

# %%
data
# Out:
#               date      county         state     fips  cases  deaths  \
# 0       2020-01-21   Snohomish    Washington  53061.0      1       0
# 1       2020-01-22   Snohomish    Washington  53061.0      1       0
# 2       2020-01-23   Snohomish    Washington  53061.0      1       0
# 3       2020-01-24   Snohomish    Washington  53061.0      1       0
# 4       2020-01-25   Snohomish    Washington  53061.0      1       0
# ...            ...         ...           ...      ...    ...     ...
# 120588  2020-05-04  Washington  Rhode Island  44009.0    363      25
# 120589  2020-05-05  Washington  Rhode Island  44009.0    363      25
# 120590  2020-05-06  Washington  Rhode Island  44009.0    363      25
# 120591  2020-05-07  Washington  Rhode Island  44009.0    363      25
# 120592  2020-05-08  Washington  Rhode Island  44009.0    363      25
#
#         population  land_area_km  density_km  state_house_blue_perc
# 0           822083          5413     151.872                  59.18
# 1           822083          5413     151.872                  59.18
# 2           822083          5413     151.872                  59.18
# 3           822083          5413     151.872                  59.18
# 4           822083          5413     151.872                  59.18
# ...            ...           ...         ...                    ...
# 120588      126979           852     149.036                  86.84
# 120589      126979           852     149.036                  86.84
# 120590      126979           852     149.036                  86.84
# 120591      126979           852     149.036                  86.84
# 120592      126979           852     149.036                  86.84
#
# [120593 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120593 entries, 0 to 120592
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   date                   120593 non-null  object
#  1   county                 120593 non-null  object
#  2   state                  120593 non-null  object
#  3   fips                   120593 non-null  float64
#  4   cases                  120593 non-null  int64
#  5   deaths                 120593 non-null  int64
#  6   population             120593 non-null  int64
#  7   land_area_km           120593 non-null  int64
#  8   density_km             120593 non-null  float64
#  9   state_house_blue_perc  120593 non-null  float64
# dtypes: float64(3), int64(4), object(3)
# memory usage: 10.1+ MB

# %%
def count_days(series):
    time_series = pd.to_datetime(series)
    first_date = time_series.iloc[0]
    last_date = time_series.iloc[-1]
    
    return (last_date - first_date).days

def case_count_county_days(series, days = 45):
    if len(series) < days:
        return series.iloc[-1]
    else:
        return series.iloc[days - 1]

# %%
def group_data(data):
    grouped_data = data.groupby(['state', 'county']).agg(
        population=('population', lambda x: x.iloc[0]),
        state_house_blue_perc=('state_house_blue_perc', lambda x: x.iloc[-1]),
        density_km=('density_km', lambda x: x.iloc[0]),
        days_counted=('date', count_days),
        case_sum=('cases', lambda x: x.iloc[-1]),
        death_sum=('deaths', lambda x: x.iloc[-1]),
        case_count_28_days=('cases', case_count_county_days),
        death_count_28_days=('deaths', case_count_county_days)
    )
    
    grouped_data = grouped_data[grouped_data['days_counted'] >= 45]
    grouped_data['confirmed_infection(%_of_pop)'] = grouped_data['case_sum']/grouped_data['population']*100
    grouped_data['death_perc(%_of_case)'] = grouped_data['death_sum']/grouped_data['case_sum']*100
    grouped_data['avg_daily_case_increase(%_of_pop)'] = grouped_data['confirmed_infection(%_of_pop)']/grouped_data['days_counted']
    grouped_data = grouped_data[grouped_data['confirmed_infection(%_of_pop)'] != float("inf")]
    grouped_data['case_count_28_days(%_of_pop)'] = grouped_data['case_count_28_days']/grouped_data['population']*100
    grouped_data['death_count_28_days(%_of_case)'] = grouped_data['death_count_28_days']/grouped_data['case_count_28_days']*100
    
    return grouped_data.reset_index()

# %%
grouped_data = group_data(data)

# %%
grouped_data
# Out:
#         state      county  population  state_house_blue_perc  density_km  \
# 0     Alabama     Autauga       54571                  22.86      35.436
# 1     Alabama     Baldwin      182265                  22.86      44.261
# 2     Alabama     Calhoun      118572                  22.86      75.572
# 3     Alabama    Chambers       34215                  22.86      22.146
# 4     Alabama     Cullman       80406                  22.86      42.252
# ...       ...         ...         ...                    ...         ...
# 1284  Wyoming     Natrona       78621                  10.00       5.684
# 1285  Wyoming        Park       28702                  10.00       1.596
# 1286  Wyoming    Sheridan       29596                  10.00       4.529
# 1287  Wyoming  Sweetwater       45267                  10.00       1.676
# 1288  Wyoming       Teton       21675                  10.00       2.088
#
#       days_counted  case_sum  death_sum  case_count_28_days  \
# 0               45        67          4                  61
# 1               55       208          5                 168
# 2               51       123          3                  93
# 3               50       311         21                 294
# 4               49        62          0                  58
# ...            ...       ...        ...                 ...
# 1284            49        48          0                  48
# 1285            52         1          0                   1
# 1286            58        16          0                  16
# 1287            45        19          0                  19
# 1288            51        98          1                  96
#
#       death_count_28_days  confirmed_infection(%_of_pop)  \
# 0                       3                       0.122776
# 1                       3                       0.114120
# 2                       3                       0.103734
# 3                      21                       0.908958
# 4                       0                       0.077109
# ...                   ...                            ...
# 1284                    0                       0.061052
# 1285                    0                       0.003484
# 1286                    0                       0.054061
# 1287                    0                       0.041973
# 1288                    1                       0.452134
#
#       death_perc(%_of_case)  avg_daily_case_increase(%_of_pop)  \
# 0                  5.970149                           0.002728
# 1                  2.403846                           0.002075
# 2                  2.439024                           0.002034
# 3                  6.752412                           0.018179
# 4                  0.000000                           0.001574
# ...                     ...                                ...
# 1284               0.000000                           0.001246
# 1285               0.000000                           0.000067
# 1286               0.000000                           0.000932
# 1287               0.000000                           0.000933
# 1288               1.020408                           0.008865
#
#       case_count_28_days(%_of_pop)  death_count_28_days(%_of_case)
# 0                         0.111781                        4.918033
# 1                         0.092173                        1.785714
# 2                         0.078433                        3.225806
# 3                         0.859272                        7.142857
# 4                         0.072134                        0.000000
# ...                            ...                             ...
# 1284                      0.061052                        0.000000
# 1285                      0.003484                        0.000000
# 1286                      0.054061                        0.000000
# 1287                      0.041973                        0.000000
# 1288                      0.442907                        1.041667
#
# [1289 rows x 15 columns]

# %%
grouped_data.sample(10)
# Out:
#           state     county  population  state_house_blue_perc  density_km  \
# 1262  Wisconsin  Jefferson       83686                  42.42      58.075
# 585    Michigan   Montcalm       63342                  42.11      33.927
# 927    Oklahoma   Canadian      115541                  18.75      49.567
# 695    Missouri    Clinton       20743                  29.41      19.118
# 481   Louisiana  Calcasieu      192768                  30.77      68.044
# 1142      Texas     Oldham        2114                  38.71       0.544
# 781    New York   Cortland       49336                  63.49      37.951
# 904        Ohio       Knox       60921                  27.27      44.631
# 575    Michigan  Kalamazoo      250331                  42.11     166.665
# 355     Indiana   Hamilton      274569                  20.00     269.185
#
#       days_counted  case_sum  death_sum  case_count_28_days  \
# 1262            49        50          0                  46
# 585             57        46          1                  29
# 927             53       107          3                  97
# 695             46        14          0                  13
# 481             50       481         38                 449
# 1142            48         3          1                   3
# 781             47        29          0                  28
# 904             46        20          1                  20
# 575             46       573         25                 539
# 355             54       913         82                 735
#
#       death_count_28_days  confirmed_infection(%_of_pop)  \
# 1262                    0                       0.059747
# 585                     1                       0.072622
# 927                     3                       0.092608
# 695                     0                       0.067493
# 481                    31                       0.249523
# 1142                    1                       0.141911
# 781                     0                       0.058781
# 904                     1                       0.032829
# 575                    23                       0.228897
# 355                    60                       0.332521
#
#       death_perc(%_of_case)  avg_daily_case_increase(%_of_pop)  \
# 1262               0.000000                           0.001219
# 585                2.173913                           0.001274
# 927                2.803738                           0.001747
# 695                0.000000                           0.001467
# 481                7.900208                           0.004990
# 1142              33.333333                           0.002956
# 781                0.000000                           0.001251
# 904                5.000000                           0.000714
# 575                4.363002                           0.004976
# 355                8.981380                           0.006158
#
#       case_count_28_days(%_of_pop)  death_count_28_days(%_of_case)
# 1262                      0.054967                        0.000000
# 585                       0.045783                        3.448276
# 927                       0.083953                        3.092784
# 695                       0.062672                        0.000000
# 481                       0.232922                        6.904232
# 1142                      0.141911                       33.333333
# 781                       0.056754                        0.000000
# 904                       0.032829                        5.000000
# 575                       0.215315                        4.267161
# 355                       0.267692                        8.163265

# %%
county_health = pd.read_csv('relevant_data/us-county-health-rankings-2020.csv')

# %%
county_health = county_health.dropna(subset=['county'])

# %%
county_health
# Out:
#        fips    state      county  num_deaths  \
# 1      1001  Alabama     Autauga       791.0
# 2      1003  Alabama     Baldwin      2967.0
# 3      1005  Alabama     Barbour       472.0
# 4      1007  Alabama        Bibb       471.0
# 5      1009  Alabama      Blount      1085.0
# ...     ...      ...         ...         ...
# 3188  56037  Wyoming  Sweetwater       532.0
# 3189  56039  Wyoming       Teton       109.0
# 3190  56041  Wyoming       Uinta       256.0
# 3191  56043  Wyoming    Washakie       110.0
# 3192  56045  Wyoming      Weston        89.0
#
#       years_of_potential_life_lost_rate  95percent_ci_low  95percent_ci_high  \
# 1                           8128.591190       7283.340731        8973.841649
# 2                           7354.122530       6918.554269        7789.690790
# 3                          10253.573403       8782.217281       11724.929524
# 4                          11977.539484      10344.064842       13611.014126
# 5                          11335.071134      10288.871387       12381.270881
# ...                                 ...               ...                ...
# 3188                        7831.827655       6915.944384        8747.710925
# 3189                        2730.603992       1991.644111        3469.563872
# 3190                        7330.683549       6011.148684        8650.218415
# 3191                        6586.049959       4500.924119        8671.175799
# 3192                        5388.706947       3608.901615        7739.082057
#
#       quartile  ypll_rate_aian  ypll_rate_aian_95percent_ci_low  ...  \
# 1          1.0             NaN                              NaN  ...
# 2          1.0             NaN                              NaN  ...
# 3          2.0             NaN                              NaN  ...
# 4          3.0             NaN                              NaN  ...
# 5          3.0             NaN                              NaN  ...
# ...        ...             ...                              ...  ...
# 3188       4.0             NaN                              NaN  ...
# 3189       1.0             NaN                              NaN  ...
# 3190       3.0             NaN                              NaN  ...
# 3191       2.0             NaN                              NaN  ...
# 3192       1.0             NaN                              NaN  ...
#
#       percent_hispanic  num_non_hispanic_white  percent_non_hispanic_white  \
# 1             2.965774                   41316                   74.308016
# 2             4.646779                  181201                   83.111337
# 3             4.276355                   11356                   45.641252
# 4             2.625000                   16708                   74.589286
# 5             9.571231                   50255                   86.886238
# ...                ...                     ...                         ...
# 3188         16.083250                   34145                   79.312908
# 3189         14.878038                   18812                   81.504268
# 3190          9.236908                   17741                   87.398394
# 3191         14.051997                    6498                   82.409639
# 3192          4.076360                    6267                   89.952634
#
#       num_not_proficient_in_english  percent_not_proficient_in_english  \
# 1                               426                           0.820225
# 2                              1068                           0.543517
# 3                               398                           1.631683
# 4                                57                           0.268210
# 5                               934                           1.724520
# ...                             ...                                ...
# 3188                            669                           1.633221
# 3189                            945                           4.314477
# 3190                            133                           0.696080
# 3191                             25                           0.324886
# 3192                             58                           0.862069
#
#       95percent_ci_low_39  95percent_ci_high_39  percent_female  num_rural  \
# 1                0.347891              1.292558       51.448715    22921.0
# 2                0.347271              0.739763       51.538377    77060.0
# 3                0.824903              2.438462       47.216752    18613.0
# 4                0.000000              0.807504       46.781250    15663.0
# 5                1.198129              2.250911       50.726141    51562.0
# ...                   ...                   ...             ...        ...
# 3188             0.993813              2.272629       48.544749     4782.0
# 3189             2.787340              5.841615       48.403449     9887.0
# 3190             0.000000              1.429709       49.332479     9101.0
# 3191             0.000000              1.376766       49.422955     3068.0
# 3192             0.000000              2.255604       47.050380     3931.0
#
#       percent_rural
# 1         42.002162
# 2         42.279099
# 3         67.789635
# 4         68.352607
# 5         89.951502
# ...             ...
# 3188      10.916313
# 3189      46.430920
# 3190      43.095937
# 3191      35.954529
# 3192      54.536626
#
# [3142 rows x 507 columns]

# %%
county_health.columns[:100]
# Out:
# Index(['fips', 'state', 'county', 'num_deaths',
#        'years_of_potential_life_lost_rate', '95percent_ci_low',
#        '95percent_ci_high', 'quartile', 'ypll_rate_aian',
#        'ypll_rate_aian_95percent_ci_low', 'ypll_rate_aian_95percent_ci_high',
#        'ypll_rate_asian', 'ypll_rate_asian_95percent_ci_low',
#        'ypll_rate_asian_95percent_ci_high', 'ypll_rate_black',
#        'ypll_rate_black_95percent_ci_low', 'ypll_rate_black_95percent_ci_high',
#        'ypll_rate_hispanic', 'ypll_rate_hispanic_95percent_ci_low',
#        'ypll_rate_hispanic_95percent_ci_high', 'ypll_rate_white',
#        'ypll_rate_white_95percent_ci_low', 'ypll_rate_white_95percent_ci_high',
#        'percent_fair_or_poor_health', '95percent_ci_low_2',
#        '95percent_ci_high_2', 'quartile_2',
#        'average_number_of_physically_unhealthy_days', '95percent_ci_low_3',
#        '95percent_ci_high_3', 'quartile_3',
#        'average_number_of_mentally_unhealthy_days', '95percent_ci_low_4',
#        '95percent_ci_high_4', 'quartile_4', 'unreliable',
#        'percent_low_birthweight', '95percent_ci_low_5', '95percent_ci_high_5',
#        'quartile_5', 'percent_lbw_aian', 'percent_lbw_aian_95percent_ci_low',
#        'percent_lbw_aian_95percent_ci_high', 'percent_lbw_asian',
#        'percent_lbw_asian_95percent_ci_low',
#        'percent_lbw_asian_95percent_ci_high', 'percent_lbw_black',
#        'percent_lbw_black_95percent_ci_low',
#        'percent_lbw_black_95percent_ci_high', 'percent_lbw_hispanic',
#        'percent_lbw_hispanic_95percent_ci_low',
#        'percent_lbw_hispanic_95percent_ci_high', 'percent_lbw_white',
#        'percent_lbw_white_95percent_ci_low',
#        'percent_lbw_white_95percent_ci_high', 'percent_smokers',
#        '95percent_ci_low_6', '95percent_ci_high_6', 'quartile_6',
#        'percent_adults_with_obesity', '95percent_ci_low_7',
#        '95percent_ci_high_7', 'quartile_7', 'food_environment_index',
#        'quartile_8', 'percent_physically_inactive', '95percent_ci_low_8',
#        '95percent_ci_high_8', 'quartile_9',
#        'percent_with_access_to_exercise_opportunities', 'quartile_10',
#        'percent_excessive_drinking', '95percent_ci_low_9',
#        '95percent_ci_high_9', 'quartile_11',
#        'num_alcohol_impaired_driving_deaths', 'num_driving_deaths',
#        'percent_driving_deaths_with_alcohol_involvement',
#        '95percent_ci_low_10', '95percent_ci_high_10', 'quartile_12',
#        'num_chlamydia_cases', 'chlamydia_rate', 'quartile_13',
#        'teen_birth_rate', '95percent_ci_low_11', '95percent_ci_high_11',
#        'quartile_14', 'teen_birth_rate_aian',
#        'teen_birth_rate_aian_95percent_ci_low',
#        'teen_birth_rate_aian_95percent_ci_high', 'teen_birth_rate_asian',
#        'teen_birth_rate_asian_95percent_ci_low',
#        'teen_birth_rate_asian_95percent_ci_high', 'teen_birth_rate_black',
#        'teen_birth_rate_black_95percent_ci_low',
#        'teen_birth_rate_black_95percent_ci_high', 'teen_birth_rate_hispanic',
#        'teen_birth_rate_hispanic_95percent_ci_low',
#        'teen_birth_rate_hispanic_95percent_ci_high'],
#       dtype='object')

# %%
excluded_column_words = [
    'quartile',
    'ci_high',
    'ci_low',
    'unreliabe',
    'petitioned',
    'fips',
    'num',
    'unreliable',
    'denominator',
    'ratio',
    'population',
    'hour_blue_perc'
]


filtered_columns = county_health.columns[~county_health.columns.str.contains('|'.join(excluded_column_words))]

# %%
len(filtered_columns)
# Out:
# 187

# %%
filtered_columns[:100]
# Out:
# Index(['state', 'county', 'years_of_potential_life_lost_rate',
#        'ypll_rate_aian', 'ypll_rate_asian', 'ypll_rate_black',
#        'ypll_rate_hispanic', 'ypll_rate_white', 'percent_fair_or_poor_health',
#        'percent_low_birthweight', 'percent_lbw_aian', 'percent_lbw_asian',
#        'percent_lbw_black', 'percent_lbw_hispanic', 'percent_lbw_white',
#        'percent_smokers', 'percent_adults_with_obesity',
#        'food_environment_index', 'percent_physically_inactive',
#        'percent_with_access_to_exercise_opportunities',
#        'percent_excessive_drinking',
#        'percent_driving_deaths_with_alcohol_involvement', 'chlamydia_rate',
#        'teen_birth_rate', 'teen_birth_rate_aian', 'teen_birth_rate_asian',
#        'teen_birth_rate_black', 'teen_birth_rate_hispanic',
#        'teen_birth_rate_white', 'percent_uninsured',
#        'primary_care_physicians_rate', 'dentist_rate',
#        'mental_health_provider_rate', 'preventable_hospitalization_rate',
#        'preventable_hosp_rate_aian', 'preventable_hosp_rate_asian',
#        'preventable_hosp_rate_black', 'preventable_hosp_rate_hispanic',
#        'preventable_hosp_rate_white', 'percent_with_annual_mammogram',
#        'percent_screened_aian', 'percent_screened_asian',
#        'percent_screened_black', 'percent_screened_hispanic',
#        'percent_screened_white', 'percent_vaccinated',
#        'percent_vaccinated_aian', 'percent_vaccinated_asian',
#        'percent_vaccinated_black', 'percent_vaccinated_hispanic',
#        'percent_vaccinated_white', 'cohort_size',
#        'high_school_graduation_rate', 'percent_some_college', 'labor_force',
#        'percent_unemployed', 'percent_children_in_poverty',
#        'percent_children_in_poverty_aian', 'percent_children_in_poverty_asian',
#        'percent_children_in_poverty_black',
#        'percent_children_in_poverty_hispanic',
#        'percent_children_in_poverty_white', '80th_percentile_income',
#        '20th_percentile_income', 'percent_single_parent_households',
#        'social_association_rate', 'annual_average_violent_crimes',
#        'violent_crime_rate', 'injury_death_rate', 'injury_death_rate_aian',
#        'injury_death_rate_asian', 'injury_death_rate_black',
#        'injury_death_rate_hispanic', 'injury_death_rate_white',
#        'average_daily_pm2_5', 'presence_of_water_violation',
#        'percent_severe_housing_problems', 'severe_housing_cost_burden',
#        'overcrowding', 'inadequate_facilities', 'percent_drive_alone_to_work',
#        'percent_drive_alone_aian', 'percent_drive_alone_asian',
#        'percent_drive_alone_black', 'percent_drive_alone_hispanic',
#        'percent_drive_alone_white', 'percent_long_commute_drives_alone',
#        'life_expectancy', 'life_expectancy_aian', 'life_expectancy_asian',
#        'life_expectancy_black', 'life_expectancy_hispanic',
#        'life_expectancy_white', 'age_adjusted_death_rate',
#        'age_adjusted_mortality_aian', 'age_adjusted_mortality_asian',
#        'age_adjusted_mortality_black', 'age_adjusted_mortality_hispanic',
#        'age_adjusted_mortality_white', 'child_mortality_rate'],
#       dtype='object')

# %%
filtered_columns[100:]
# Out:
# Index(['child_mortality_rate_aian', 'child_mortality_rate_asian',
#        'child_mortality_rate_black', 'child_mortality_rate_hispanic',
#        'child_mortality_rate_white', 'infant_mortality_rate',
#        'infant_mortality_rate_aian', 'infant_mortality_rate_asian',
#        'infant_mortality_rate_black', 'infant_mortality_rate_hispanic',
#        'infant_mortality_rate_white', 'percent_frequent_physical_distress',
#        'percent_frequent_mental_distress', 'percent_adults_with_diabetes',
#        'hiv_prevalence_rate', 'percent_food_insecure',
#        'percent_limited_access_to_healthy_foods',
#        'drug_overdose_mortality_rate', 'drug_overdose_mortality_rate_aian',
#        'drug_overdose_mortality_rate_asian',
#        'drug_overdose_mortality_rate_black',
#        'drug_overdose_mortality_rate_hispanic',
#        'drug_overdose_mortality_rate_white', 'motor_vehicle_mortality_rate',
#        'mv_mortality_rate_aian', 'mv_mortality_rate_asian',
#        'mv_mortality_rate_black', 'mv_mortality_rate_hispanic',
#        'mv_mortality_rate_white', 'percent_insufficient_sleep',
#        'percent_uninsured_2', 'percent_uninsured_3',
#        'other_primary_care_provider_rate', 'percent_disconnected_youth',
#        'average_grade_performance', 'average_grade_performance_asian',
#        'average_grade_performance_black', 'average_grade_performance_hispanic',
#        'average_grade_performance_white', 'average_grade_performance_2',
#        'average_grade_performance_asian_2',
#        'average_grade_performance_black_2',
#        'average_grade_performance_hispanic_2',
#        'average_grade_performance_white_2', 'median_household_income',
#        'household_income_aian', 'household_income_asian',
#        'household_income_black', 'household_income_hispanic',
#        'household_income_white', 'percent_enrolled_in_free_or_reduced_lunch',
#        'segregation_index', 'segregation_index_2', 'homicide_rate',
#        'homicide_rate_aian', 'homicide_rate_asian', 'homicide_rate_black',
#        'homicide_rate_hispanic', 'homicide_rate_white',
#        'suicide_rate_age_adjusted', 'crude_rate', 'suicide_rate_aian',
#        'suicide_rate_asian', 'suicide_rate_black', 'suicide_rate_hispanic',
#        'suicide_rate_white', 'firearm_fatalities_rate',
#        'firearm_fatalities_rate_aian', 'firearm_fatalities_rate_asian',
#        'firearm_fatalities_rate_black', 'firearm_fatalities_rate_hispanic',
#        'firearm_fatalities_rate_white', 'juvenile_arrest_rate',
#        'average_traffic_volume_per_meter_of_major_roadways',
#        'percent_homeowners', 'percent_severe_housing_cost_burden',
#        'percent_less_than_18_years_of_age', 'percent_65_and_over',
#        'percent_black', 'percent_american_indian_alaska_native',
#        'percent_asian', 'percent_native_hawaiian_other_pacific_islander',
#        'percent_hispanic', 'percent_non_hispanic_white',
#        'percent_not_proficient_in_english', 'percent_female', 'percent_rural'],
#       dtype='object')

# %%
filtered_county_health = county_health[filtered_columns]

# %%
filtered_county_health
# Out:
#         state      county  years_of_potential_life_lost_rate  ypll_rate_aian  \
# 1     Alabama     Autauga                        8128.591190             NaN
# 2     Alabama     Baldwin                        7354.122530             NaN
# 3     Alabama     Barbour                       10253.573403             NaN
# 4     Alabama        Bibb                       11977.539484             NaN
# 5     Alabama      Blount                       11335.071134             NaN
# ...       ...         ...                                ...             ...
# 3188  Wyoming  Sweetwater                        7831.827655             NaN
# 3189  Wyoming       Teton                        2730.603992             NaN
# 3190  Wyoming       Uinta                        7330.683549             NaN
# 3191  Wyoming    Washakie                        6586.049959             NaN
# 3192  Wyoming      Weston                        5388.706947             NaN
#
#       ypll_rate_asian  ypll_rate_black  ypll_rate_hispanic  ypll_rate_white  \
# 1                 NaN     10201.389930                 NaN      7885.665369
# 2                 NaN      9890.505276         3570.475265      7435.761186
# 3                 NaN     12422.166370                 NaN      8140.174177
# 4                 NaN     13085.045008                 NaN     12241.384199
# 5                 NaN              NaN                 NaN              NaN
# ...               ...              ...                 ...              ...
# 3188              NaN              NaN         5475.015989      8246.109906
# 3189              NaN              NaN                 NaN              NaN
# 3190              NaN              NaN                 NaN              NaN
# 3191              NaN              NaN                 NaN              NaN
# 3192              NaN              NaN                 NaN              NaN
#
#       percent_fair_or_poor_health  percent_low_birthweight  ...  \
# 1                       20.882987                 8.619529  ...
# 2                       17.509134                 8.345003  ...
# 3                       29.591802                11.474559  ...
# 4                       19.439724                10.308710  ...
# 5                       21.745293                 7.604563  ...
# ...                           ...                      ...  ...
# 3188                    14.813082                 9.705248  ...
# 3189                    11.914358                 7.736721  ...
# 3190                    15.537464                10.110206  ...
# 3191                    15.955971                 7.028754  ...
# 3192                    13.934025                 6.589147  ...
#
#       percent_65_and_over  percent_black  \
# 1               15.562670      19.343177
# 2               20.443350       8.783976
# 3               19.420441      48.032635
# 4               16.473214      21.120536
# 5               18.236515       1.462656
# ...                   ...            ...
# 3188            12.111217       1.145153
# 3189            15.415277       0.632555
# 3190            14.079511       0.684763
# 3191            21.686747       0.469245
# 3192            20.510980       0.645902
#
#       percent_american_indian_alaska_native  percent_asian  \
# 1                                  0.480207       1.224798
# 2                                  0.772399       1.150343
# 3                                  0.659137       0.454162
# 4                                  0.437500       0.236607
# 5                                  0.653527       0.319848
# ...                                     ...            ...
# 3188                               1.544680       1.010429
# 3189                               0.914172       1.412417
# 3190                               1.418789       0.472930
# 3191                               1.813570       0.824350
# 3192                               1.765466       1.937706
#
#       percent_native_hawaiian_other_pacific_islander  percent_hispanic  \
# 1                                           0.111509          2.965774
# 2                                           0.066966          4.646779
# 3                                           0.184880          4.276355
# 4                                           0.116071          2.625000
# 5                                           0.121024          9.571231
# ...                                              ...               ...
# 3188                                        0.157952         16.083250
# 3189                                        0.151640         14.878038
# 3190                                        0.147791          9.236908
# 3191                                        0.101458         14.051997
# 3192                                        0.028707          4.076360
#
#       percent_non_hispanic_white  percent_not_proficient_in_english  \
# 1                      74.308016                           0.820225
# 2                      83.111337                           0.543517
# 3                      45.641252                           1.631683
# 4                      74.589286                           0.268210
# 5                      86.886238                           1.724520
# ...                          ...                                ...
# 3188                   79.312908                           1.633221
# 3189                   81.504268                           4.314477
# 3190                   87.398394                           0.696080
# 3191                   82.409639                           0.324886
# 3192                   89.952634                           0.862069
#
#       percent_female  percent_rural
# 1          51.448715      42.002162
# 2          51.538377      42.279099
# 3          47.216752      67.789635
# 4          46.781250      68.352607
# 5          50.726141      89.951502
# ...              ...            ...
# 3188       48.544749      10.916313
# 3189       48.403449      46.430920
# 3190       49.332479      43.095937
# 3191       49.422955      35.954529
# 3192       47.050380      54.536626
#
# [3142 rows x 187 columns]

# %%
filtered_county_health.info(max_cols=200)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3142 entries, 1 to 3192
# Data columns (total 187 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   state                                               3142 non-null   object
#  1   county                                              3142 non-null   object
#  2   years_of_potential_life_lost_rate                   2849 non-null   float64
#  3   ypll_rate_aian                                      175 non-null    float64
#  4   ypll_rate_asian                                     224 non-null    float64
#  5   ypll_rate_black                                     1030 non-null   float64
#  6   ypll_rate_hispanic                                  646 non-null    float64
#  7   ypll_rate_white                                     1283 non-null   float64
#  8   percent_fair_or_poor_health                         3142 non-null   float64
#  9   percent_low_birthweight                             3035 non-null   float64
#  10  percent_lbw_aian                                    324 non-null    float64
#  11  percent_lbw_asian                                   691 non-null    float64
#  12  percent_lbw_black                                   1415 non-null   float64
#  13  percent_lbw_hispanic                                1424 non-null   float64
#  14  percent_lbw_white                                   1913 non-null   float64
#  15  percent_smokers                                     3142 non-null   float64
#  16  percent_adults_with_obesity                         3142 non-null   float64
#  17  food_environment_index                              3123 non-null   float64
#  18  percent_physically_inactive                         3142 non-null   float64
#  19  percent_with_access_to_exercise_opportunities       3136 non-null   float64
#  20  percent_excessive_drinking                          3142 non-null   float64
#  21  percent_driving_deaths_with_alcohol_involvement     3107 non-null   float64
#  22  chlamydia_rate                                      2990 non-null   float64
#  23  teen_birth_rate                                     2987 non-null   float64
#  24  teen_birth_rate_aian                                354 non-null    float64
#  25  teen_birth_rate_asian                               295 non-null    float64
#  26  teen_birth_rate_black                               1366 non-null   float64
#  27  teen_birth_rate_hispanic                            1546 non-null   float64
#  28  teen_birth_rate_white                               1958 non-null   float64
#  29  percent_uninsured                                   3141 non-null   float64
#  30  primary_care_physicians_rate                        2995 non-null   float64
#  31  dentist_rate                                        3054 non-null   float64
#  32  mental_health_provider_rate                         2912 non-null   float64
#  33  preventable_hospitalization_rate                    3099 non-null   float64
#  34  preventable_hosp_rate_aian                          401 non-null    float64
#  35  preventable_hosp_rate_asian                         427 non-null    float64
#  36  preventable_hosp_rate_black                         1473 non-null   float64
#  37  preventable_hosp_rate_hispanic                      1068 non-null   float64
#  38  preventable_hosp_rate_white                         1908 non-null   float64
#  39  percent_with_annual_mammogram                       3123 non-null   float64
#  40  percent_screened_aian                               447 non-null    float64
#  41  percent_screened_asian                              876 non-null    float64
#  42  percent_screened_black                              1543 non-null   float64
#  43  percent_screened_hispanic                           1376 non-null   float64
#  44  percent_screened_white                              2079 non-null   float64
#  45  percent_vaccinated                                  3124 non-null   float64
#  46  percent_vaccinated_aian                             697 non-null    float64
#  47  percent_vaccinated_asian                            1154 non-null   float64
#  48  percent_vaccinated_black                            1857 non-null   float64
#  49  percent_vaccinated_hispanic                         1825 non-null   float64
#  50  percent_vaccinated_white                            2432 non-null   float64
#  51  cohort_size                                         2494 non-null   float64
#  52  high_school_graduation_rate                         3046 non-null   float64
#  53  percent_some_college                                3142 non-null   float64
#  54  labor_force                                         3141 non-null   float64
#  55  percent_unemployed                                  3141 non-null   float64
#  56  percent_children_in_poverty                         3141 non-null   float64
#  57  percent_children_in_poverty_aian                    840 non-null    float64
#  58  percent_children_in_poverty_asian                   888 non-null    float64
#  59  percent_children_in_poverty_black                   1798 non-null   float64
#  60  percent_children_in_poverty_hispanic                2554 non-null   float64
#  61  percent_children_in_poverty_white                   2765 non-null   float64
#  62  80th_percentile_income                              3140 non-null   float64
#  63  20th_percentile_income                              3140 non-null   float64
#  64  percent_single_parent_households                    3140 non-null   float64
#  65  social_association_rate                             3142 non-null   float64
#  66  annual_average_violent_crimes                       2951 non-null   float64
#  67  violent_crime_rate                                  2951 non-null   float64
#  68  injury_death_rate                                   3042 non-null   float64
#  69  injury_death_rate_aian                              248 non-null    float64
#  70  injury_death_rate_asian                             275 non-null    float64
#  71  injury_death_rate_black                             1081 non-null   float64
#  72  injury_death_rate_hispanic                          794 non-null    float64
#  73  injury_death_rate_white                             1442 non-null   float64
#  74  average_daily_pm2_5                                 3108 non-null   float64
#  75  presence_of_water_violation                         3099 non-null   object
#  76  percent_severe_housing_problems                     3142 non-null   float64
#  77  severe_housing_cost_burden                          3142 non-null   float64
#  78  overcrowding                                        3142 non-null   float64
#  79  inadequate_facilities                               3142 non-null   float64
#  80  percent_drive_alone_to_work                         3141 non-null   float64
#  81  percent_drive_alone_aian                            407 non-null    float64
#  82  percent_drive_alone_asian                           587 non-null    float64
#  83  percent_drive_alone_black                           1172 non-null   float64
#  84  percent_drive_alone_hispanic                        1292 non-null   float64
#  85  percent_drive_alone_white                           1762 non-null   float64
#  86  percent_long_commute_drives_alone                   3141 non-null   float64
#  87  life_expectancy                                     3069 non-null   float64
#  88  life_expectancy_aian                                312 non-null    float64
#  89  life_expectancy_asian                               579 non-null    float64
#  90  life_expectancy_black                               1319 non-null   float64
#  91  life_expectancy_hispanic                            1172 non-null   float64
#  92  life_expectancy_white                               1746 non-null   float64
#  93  age_adjusted_death_rate                             3082 non-null   float64
#  94  age_adjusted_mortality_aian                         328 non-null    float64
#  95  age_adjusted_mortality_asian                        362 non-null    float64
#  96  age_adjusted_mortality_black                        1354 non-null   float64
#  97  age_adjusted_mortality_hispanic                     852 non-null    float64
#  98  age_adjusted_mortality_white                        1691 non-null   float64
#  99  child_mortality_rate                                1911 non-null   float64
#  100 child_mortality_rate_aian                           33 non-null     float64
#  101 child_mortality_rate_asian                          119 non-null    float64
#  102 child_mortality_rate_black                          500 non-null    float64
#  103 child_mortality_rate_hispanic                       376 non-null    float64
#  104 child_mortality_rate_white                          631 non-null    float64
#  105 infant_mortality_rate                               1258 non-null   float64
#  106 infant_mortality_rate_aian                          7 non-null      float64
#  107 infant_mortality_rate_asian                         65 non-null     float64
#  108 infant_mortality_rate_black                         349 non-null    float64
#  109 infant_mortality_rate_hispanic                      235 non-null    float64
#  110 infant_mortality_rate_white                         408 non-null    float64
#  111 percent_frequent_physical_distress                  3142 non-null   float64
#  112 percent_frequent_mental_distress                    3142 non-null   float64
#  113 percent_adults_with_diabetes                        3142 non-null   float64
#  114 hiv_prevalence_rate                                 2283 non-null   float64
#  115 percent_food_insecure                               3142 non-null   float64
#  116 percent_limited_access_to_healthy_foods             3123 non-null   float64
#  117 drug_overdose_mortality_rate                        1722 non-null   float64
#  118 drug_overdose_mortality_rate_aian                   39 non-null     float64
#  119 drug_overdose_mortality_rate_asian                  38 non-null     float64
#  120 drug_overdose_mortality_rate_black                  317 non-null    float64
#  121 drug_overdose_mortality_rate_hispanic               239 non-null    float64
#  122 drug_overdose_mortality_rate_white                  397 non-null    float64
#  123 motor_vehicle_mortality_rate                        2698 non-null   float64
#  124 mv_mortality_rate_aian                              82 non-null     float64
#  125 mv_mortality_rate_asian                             111 non-null    float64
#  126 mv_mortality_rate_black                             619 non-null    float64
#  127 mv_mortality_rate_hispanic                          442 non-null    float64
#  128 mv_mortality_rate_white                             845 non-null    float64
#  129 percent_insufficient_sleep                          3142 non-null   float64
#  130 percent_uninsured_2                                 3141 non-null   float64
#  131 percent_uninsured_3                                 3141 non-null   float64
#  132 other_primary_care_provider_rate                    3120 non-null   float64
#  133 percent_disconnected_youth                          1376 non-null   float64
#  134 average_grade_performance                           2506 non-null   float64
#  135 average_grade_performance_asian                     255 non-null    float64
#  136 average_grade_performance_black                     891 non-null    float64
#  137 average_grade_performance_hispanic                  958 non-null    float64
#  138 average_grade_performance_white                     1253 non-null   float64
#  139 average_grade_performance_2                         2468 non-null   float64
#  140 average_grade_performance_asian_2                   342 non-null    float64
#  141 average_grade_performance_black_2                   889 non-null    float64
#  142 average_grade_performance_hispanic_2                1018 non-null   float64
#  143 average_grade_performance_white_2                   1268 non-null   float64
#  144 median_household_income                             3141 non-null   float64
#  145 household_income_aian                               1397 non-null   float64
#  146 household_income_asian                              1374 non-null   float64
#  147 household_income_black                              1940 non-null   float64
#  148 household_income_hispanic                           2464 non-null   float64
#  149 household_income_white                              2867 non-null   float64
#  150 percent_enrolled_in_free_or_reduced_lunch           3020 non-null   float64
#  151 segregation_index                                   2069 non-null   float64
#  152 segregation_index_2                                 2791 non-null   float64
#  153 homicide_rate                                       1284 non-null   float64
#  154 homicide_rate_aian                                  22 non-null     float64
#  155 homicide_rate_asian                                 47 non-null     float64
#  156 homicide_rate_black                                 442 non-null    float64
#  157 homicide_rate_hispanic                              221 non-null    float64
#  158 homicide_rate_white                                 487 non-null    float64
#  159 suicide_rate_age_adjusted                           2379 non-null   float64
#  160 crude_rate                                          2379 non-null   float64
#  161 suicide_rate_aian                                   51 non-null     float64
#  162 suicide_rate_asian                                  119 non-null    float64
#  163 suicide_rate_black                                  258 non-null    float64
#  164 suicide_rate_hispanic                               282 non-null    float64
#  165 suicide_rate_white                                  410 non-null    float64
#  166 firearm_fatalities_rate                             2226 non-null   float64
#  167 firearm_fatalities_rate_aian                        30 non-null     float64
#  168 firearm_fatalities_rate_asian                       59 non-null     float64
#  169 firearm_fatalities_rate_black                       487 non-null    float64
#  170 firearm_fatalities_rate_hispanic                    247 non-null    float64
#  171 firearm_fatalities_rate_white                       581 non-null    float64
#  172 juvenile_arrest_rate                                2139 non-null   float64
#  173 average_traffic_volume_per_meter_of_major_roadways  3142 non-null   float64
#  174 percent_homeowners                                  3142 non-null   float64
#  175 percent_severe_housing_cost_burden                  3138 non-null   float64
#  176 percent_less_than_18_years_of_age                   3142 non-null   float64
#  177 percent_65_and_over                                 3142 non-null   float64
#  178 percent_black                                       3142 non-null   float64
#  179 percent_american_indian_alaska_native               3142 non-null   float64
#  180 percent_asian                                       3142 non-null   float64
#  181 percent_native_hawaiian_other_pacific_islander      3142 non-null   float64
#  182 percent_hispanic                                    3142 non-null   float64
#  183 percent_non_hispanic_white                          3142 non-null   float64
#  184 percent_not_proficient_in_english                   3142 non-null   float64
#  185 percent_female                                      3142 non-null   float64
#  186 percent_rural                                       3135 non-null   float64
# dtypes: float64(184), object(3)
# memory usage: 4.5+ MB

# %%
complete_data = grouped_data.merge(
    filtered_county_health, left_on=['county', 'state'], right_on=['county', 'state']
)

# %%
complete_data.info(max_cols=200)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1288 entries, 0 to 1287
# Data columns (total 200 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   state                                               1288 non-null   object
#  1   county                                              1288 non-null   object
#  2   population                                          1288 non-null   int64
#  3   state_house_blue_perc                               1288 non-null   float64
#  4   density_km                                          1288 non-null   float64
#  5   days_counted                                        1288 non-null   int64
#  6   case_sum                                            1288 non-null   int64
#  7   death_sum                                           1288 non-null   int64
#  8   case_count_28_days                                  1288 non-null   int64
#  9   death_count_28_days                                 1288 non-null   int64
#  10  confirmed_infection(%_of_pop)                       1288 non-null   float64
#  11  death_perc(%_of_case)                               1288 non-null   float64
#  12  avg_daily_case_increase(%_of_pop)                   1288 non-null   float64
#  13  case_count_28_days(%_of_pop)                        1288 non-null   float64
#  14  death_count_28_days(%_of_case)                      1288 non-null   float64
#  15  years_of_potential_life_lost_rate                   1277 non-null   float64
#  16  ypll_rate_aian                                      111 non-null    float64
#  17  ypll_rate_asian                                     209 non-null    float64
#  18  ypll_rate_black                                     729 non-null    float64
#  19  ypll_rate_hispanic                                  496 non-null    float64
#  20  ypll_rate_white                                     847 non-null    float64
#  21  percent_fair_or_poor_health                         1288 non-null   float64
#  22  percent_low_birthweight                             1286 non-null   float64
#  23  percent_lbw_aian                                    203 non-null    float64
#  24  percent_lbw_asian                                   586 non-null    float64
#  25  percent_lbw_black                                   911 non-null    float64
#  26  percent_lbw_hispanic                                907 non-null    float64
#  27  percent_lbw_white                                   1088 non-null   float64
#  28  percent_smokers                                     1288 non-null   float64
#  29  percent_adults_with_obesity                         1288 non-null   float64
#  30  food_environment_index                              1285 non-null   float64
#  31  percent_physically_inactive                         1288 non-null   float64
#  32  percent_with_access_to_exercise_opportunities       1288 non-null   float64
#  33  percent_excessive_drinking                          1288 non-null   float64
#  34  percent_driving_deaths_with_alcohol_involvement     1288 non-null   float64
#  35  chlamydia_rate                                      1285 non-null   float64
#  36  teen_birth_rate                                     1286 non-null   float64
#  37  teen_birth_rate_aian                                213 non-null    float64
#  38  teen_birth_rate_asian                               252 non-null    float64
#  39  teen_birth_rate_black                               877 non-null    float64
#  40  teen_birth_rate_hispanic                            930 non-null    float64
#  41  teen_birth_rate_white                               1080 non-null   float64
#  42  percent_uninsured                                   1288 non-null   float64
#  43  primary_care_physicians_rate                        1277 non-null   float64
#  44  dentist_rate                                        1277 non-null   float64
#  45  mental_health_provider_rate                         1272 non-null   float64
#  46  preventable_hospitalization_rate                    1286 non-null   float64
#  47  preventable_hosp_rate_aian                          238 non-null    float64
#  48  preventable_hosp_rate_asian                         378 non-null    float64
#  49  preventable_hosp_rate_black                         896 non-null    float64
#  50  preventable_hosp_rate_hispanic                      696 non-null    float64
#  51  preventable_hosp_rate_white                         1042 non-null   float64
#  52  percent_with_annual_mammogram                       1287 non-null   float64
#  53  percent_screened_aian                               259 non-null    float64
#  54  percent_screened_asian                              709 non-null    float64
#  55  percent_screened_black                              937 non-null    float64
#  56  percent_screened_hispanic                           871 non-null    float64
#  57  percent_screened_white                              1114 non-null   float64
#  58  percent_vaccinated                                  1287 non-null   float64
#  59  percent_vaccinated_aian                             408 non-null    float64
#  60  percent_vaccinated_asian                            851 non-null    float64
#  61  percent_vaccinated_black                            1073 non-null   float64
#  62  percent_vaccinated_hispanic                         1042 non-null   float64
#  63  percent_vaccinated_white                            1207 non-null   float64
#  64  cohort_size                                         1155 non-null   float64
#  65  high_school_graduation_rate                         1284 non-null   float64
#  66  percent_some_college                                1288 non-null   float64
#  67  labor_force                                         1288 non-null   float64
#  68  percent_unemployed                                  1288 non-null   float64
#  69  percent_children_in_poverty                         1288 non-null   float64
#  70  percent_children_in_poverty_aian                    498 non-null    float64
#  71  percent_children_in_poverty_asian                   687 non-null    float64
#  72  percent_children_in_poverty_black                   1048 non-null   float64
#  73  percent_children_in_poverty_hispanic                1188 non-null   float64
#  74  percent_children_in_poverty_white                   1255 non-null   float64
#  75  80th_percentile_income                              1288 non-null   float64
#  76  20th_percentile_income                              1288 non-null   float64
#  77  percent_single_parent_households                    1288 non-null   float64
#  78  social_association_rate                             1288 non-null   float64
#  79  annual_average_violent_crimes                       1233 non-null   float64
#  80  violent_crime_rate                                  1233 non-null   float64
#  81  injury_death_rate                                   1286 non-null   float64
#  82  injury_death_rate_aian                              150 non-null    float64
#  83  injury_death_rate_asian                             253 non-null    float64
#  84  injury_death_rate_black                             747 non-null    float64
#  85  injury_death_rate_hispanic                          580 non-null    float64
#  86  injury_death_rate_white                             901 non-null    float64
#  87  average_daily_pm2_5                                 1283 non-null   float64
#  88  presence_of_water_violation                         1284 non-null   object
#  89  percent_severe_housing_problems                     1288 non-null   float64
#  90  severe_housing_cost_burden                          1288 non-null   float64
#  91  overcrowding                                        1288 non-null   float64
#  92  inadequate_facilities                               1288 non-null   float64
#  93  percent_drive_alone_to_work                         1288 non-null   float64
#  94  percent_drive_alone_aian                            244 non-null    float64
#  95  percent_drive_alone_asian                           508 non-null    float64
#  96  percent_drive_alone_black                           815 non-null    float64
#  97  percent_drive_alone_hispanic                        842 non-null    float64
#  98  percent_drive_alone_white                           1023 non-null   float64
#  99  percent_long_commute_drives_alone                   1288 non-null   float64
#  100 life_expectancy                                     1287 non-null   float64
#  101 life_expectancy_aian                                211 non-null    float64
#  102 life_expectancy_asian                               515 non-null    float64
#  103 life_expectancy_black                               867 non-null    float64
#  104 life_expectancy_hispanic                            793 non-null    float64
#  105 life_expectancy_white                               1029 non-null   float64
#  106 age_adjusted_death_rate                             1287 non-null   float64
#  107 age_adjusted_mortality_aian                         204 non-null    float64
#  108 age_adjusted_mortality_asian                        329 non-null    float64
#  109 age_adjusted_mortality_black                        863 non-null    float64
#  110 age_adjusted_mortality_hispanic                     603 non-null    float64
#  111 age_adjusted_mortality_white                        983 non-null    float64
#  112 child_mortality_rate                                1118 non-null   float64
#  113 child_mortality_rate_aian                           23 non-null     float64
#  114 child_mortality_rate_asian                          113 non-null    float64
#  115 child_mortality_rate_black                          432 non-null    float64
#  116 child_mortality_rate_hispanic                       329 non-null    float64
#  117 child_mortality_rate_white                          529 non-null    float64
#  118 infant_mortality_rate                               918 non-null    float64
#  119 infant_mortality_rate_aian                          7 non-null      float64
#  120 infant_mortality_rate_asian                         61 non-null     float64
#  121 infant_mortality_rate_black                         314 non-null    float64
#  122 infant_mortality_rate_hispanic                      214 non-null    float64
#  123 infant_mortality_rate_white                         365 non-null    float64
#  124 percent_frequent_physical_distress                  1288 non-null   float64
#  125 percent_frequent_mental_distress                    1288 non-null   float64
#  126 percent_adults_with_diabetes                        1288 non-null   float64
#  127 hiv_prevalence_rate                                 1135 non-null   float64
#  128 percent_food_insecure                               1288 non-null   float64
#  129 percent_limited_access_to_healthy_foods             1285 non-null   float64
#  130 drug_overdose_mortality_rate                        1043 non-null   float64
#  131 drug_overdose_mortality_rate_aian                   33 non-null     float64
#  132 drug_overdose_mortality_rate_asian                  35 non-null     float64
#  133 drug_overdose_mortality_rate_black                  285 non-null    float64
#  134 drug_overdose_mortality_rate_hispanic               218 non-null    float64
#  135 drug_overdose_mortality_rate_white                  349 non-null    float64
#  136 motor_vehicle_mortality_rate                        1257 non-null   float64
#  137 mv_mortality_rate_aian                              51 non-null     float64
#  138 mv_mortality_rate_asian                             105 non-null    float64
#  139 mv_mortality_rate_black                             480 non-null    float64
#  140 mv_mortality_rate_hispanic                          345 non-null    float64
#  141 mv_mortality_rate_white                             611 non-null    float64
#  142 percent_insufficient_sleep                          1288 non-null   float64
#  143 percent_uninsured_2                                 1288 non-null   float64
#  144 percent_uninsured_3                                 1288 non-null   float64
#  145 other_primary_care_provider_rate                    1287 non-null   float64
#  146 percent_disconnected_youth                          905 non-null    float64
#  147 average_grade_performance                           975 non-null    float64
#  148 average_grade_performance_asian                     226 non-null    float64
#  149 average_grade_performance_black                     571 non-null    float64
#  150 average_grade_performance_hispanic                  558 non-null    float64
#  151 average_grade_performance_white                     689 non-null    float64
#  152 average_grade_performance_2                         980 non-null    float64
#  153 average_grade_performance_asian_2                   299 non-null    float64
#  154 average_grade_performance_black_2                   577 non-null    float64
#  155 average_grade_performance_hispanic_2                596 non-null    float64
#  156 average_grade_performance_white_2                   698 non-null    float64
#  157 median_household_income                             1288 non-null   float64
#  158 household_income_aian                               776 non-null    float64
#  159 household_income_asian                              888 non-null    float64
#  160 household_income_black                              1067 non-null   float64
#  161 household_income_hispanic                           1150 non-null   float64
#  162 household_income_white                              1261 non-null   float64
#  163 percent_enrolled_in_free_or_reduced_lunch           1222 non-null   float64
#  164 segregation_index                                   1140 non-null   float64
#  165 segregation_index_2                                 1274 non-null   float64
#  166 homicide_rate                                       878 non-null    float64
#  167 homicide_rate_aian                                  21 non-null     float64
#  168 homicide_rate_asian                                 44 non-null     float64
#  169 homicide_rate_black                                 392 non-null    float64
#  170 homicide_rate_hispanic                              198 non-null    float64
#  171 homicide_rate_white                                 428 non-null    float64
#  172 suicide_rate_age_adjusted                           1212 non-null   float64
#  173 crude_rate                                          1212 non-null   float64
#  174 suicide_rate_aian                                   38 non-null     float64
#  175 suicide_rate_asian                                  112 non-null    float64
#  176 suicide_rate_black                                  233 non-null    float64
#  177 suicide_rate_hispanic                               247 non-null    float64
#  178 suicide_rate_white                                  351 non-null    float64
#  179 firearm_fatalities_rate                             1190 non-null   float64
#  180 firearm_fatalities_rate_aian                        22 non-null     float64
#  181 firearm_fatalities_rate_asian                       56 non-null     float64
#  182 firearm_fatalities_rate_black                       415 non-null    float64
#  183 firearm_fatalities_rate_hispanic                    212 non-null    float64
#  184 firearm_fatalities_rate_white                       478 non-null    float64
#  185 juvenile_arrest_rate                                966 non-null    float64
#  186 average_traffic_volume_per_meter_of_major_roadways  1288 non-null   float64
#  187 percent_homeowners                                  1288 non-null   float64
#  188 percent_severe_housing_cost_burden                  1288 non-null   float64
#  189 percent_less_than_18_years_of_age                   1288 non-null   float64
#  190 percent_65_and_over                                 1288 non-null   float64
#  191 percent_black                                       1288 non-null   float64
#  192 percent_american_indian_alaska_native               1288 non-null   float64
#  193 percent_asian                                       1288 non-null   float64
#  194 percent_native_hawaiian_other_pacific_islander      1288 non-null   float64
#  195 percent_hispanic                                    1288 non-null   float64
#  196 percent_non_hispanic_white                          1288 non-null   float64
#  197 percent_not_proficient_in_english                   1288 non-null   float64
#  198 percent_female                                      1288 non-null   float64
#  199 percent_rural                                       1288 non-null   float64
# dtypes: float64(191), int64(6), object(3)
# memory usage: 2.0+ MB

# %%
complete_data.dropna(thresh=1260, axis=1).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1288 entries, 0 to 1287
# Data columns (total 80 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   state                                               1288 non-null   object
#  1   county                                              1288 non-null   object
#  2   population                                          1288 non-null   int64
#  3   state_house_blue_perc                               1288 non-null   float64
#  4   density_km                                          1288 non-null   float64
#  5   days_counted                                        1288 non-null   int64
#  6   case_sum                                            1288 non-null   int64
#  7   death_sum                                           1288 non-null   int64
#  8   case_count_28_days                                  1288 non-null   int64
#  9   death_count_28_days                                 1288 non-null   int64
#  10  confirmed_infection(%_of_pop)                       1288 non-null   float64
#  11  death_perc(%_of_case)                               1288 non-null   float64
#  12  avg_daily_case_increase(%_of_pop)                   1288 non-null   float64
#  13  case_count_28_days(%_of_pop)                        1288 non-null   float64
#  14  death_count_28_days(%_of_case)                      1288 non-null   float64
#  15  years_of_potential_life_lost_rate                   1277 non-null   float64
#  16  percent_fair_or_poor_health                         1288 non-null   float64
#  17  percent_low_birthweight                             1286 non-null   float64
#  18  percent_smokers                                     1288 non-null   float64
#  19  percent_adults_with_obesity                         1288 non-null   float64
#  20  food_environment_index                              1285 non-null   float64
#  21  percent_physically_inactive                         1288 non-null   float64
#  22  percent_with_access_to_exercise_opportunities       1288 non-null   float64
#  23  percent_excessive_drinking                          1288 non-null   float64
#  24  percent_driving_deaths_with_alcohol_involvement     1288 non-null   float64
#  25  chlamydia_rate                                      1285 non-null   float64
#  26  teen_birth_rate                                     1286 non-null   float64
#  27  percent_uninsured                                   1288 non-null   float64
#  28  primary_care_physicians_rate                        1277 non-null   float64
#  29  dentist_rate                                        1277 non-null   float64
#  30  mental_health_provider_rate                         1272 non-null   float64
#  31  preventable_hospitalization_rate                    1286 non-null   float64
#  32  percent_with_annual_mammogram                       1287 non-null   float64
#  33  percent_vaccinated                                  1287 non-null   float64
#  34  high_school_graduation_rate                         1284 non-null   float64
#  35  percent_some_college                                1288 non-null   float64
#  36  labor_force                                         1288 non-null   float64
#  37  percent_unemployed                                  1288 non-null   float64
#  38  percent_children_in_poverty                         1288 non-null   float64
#  39  80th_percentile_income                              1288 non-null   float64
#  40  20th_percentile_income                              1288 non-null   float64
#  41  percent_single_parent_households                    1288 non-null   float64
#  42  social_association_rate                             1288 non-null   float64
#  43  injury_death_rate                                   1286 non-null   float64
#  44  average_daily_pm2_5                                 1283 non-null   float64
#  45  presence_of_water_violation                         1284 non-null   object
#  46  percent_severe_housing_problems                     1288 non-null   float64
#  47  severe_housing_cost_burden                          1288 non-null   float64
#  48  overcrowding                                        1288 non-null   float64
#  49  inadequate_facilities                               1288 non-null   float64
#  50  percent_drive_alone_to_work                         1288 non-null   float64
#  51  percent_long_commute_drives_alone                   1288 non-null   float64
#  52  life_expectancy                                     1287 non-null   float64
#  53  age_adjusted_death_rate                             1287 non-null   float64
#  54  percent_frequent_physical_distress                  1288 non-null   float64
#  55  percent_frequent_mental_distress                    1288 non-null   float64
#  56  percent_adults_with_diabetes                        1288 non-null   float64
#  57  percent_food_insecure                               1288 non-null   float64
#  58  percent_limited_access_to_healthy_foods             1285 non-null   float64
#  59  percent_insufficient_sleep                          1288 non-null   float64
#  60  percent_uninsured_2                                 1288 non-null   float64
#  61  percent_uninsured_3                                 1288 non-null   float64
#  62  other_primary_care_provider_rate                    1287 non-null   float64
#  63  median_household_income                             1288 non-null   float64
#  64  household_income_white                              1261 non-null   float64
#  65  segregation_index_2                                 1274 non-null   float64
#  66  average_traffic_volume_per_meter_of_major_roadways  1288 non-null   float64
#  67  percent_homeowners                                  1288 non-null   float64
#  68  percent_severe_housing_cost_burden                  1288 non-null   float64
#  69  percent_less_than_18_years_of_age                   1288 non-null   float64
#  70  percent_65_and_over                                 1288 non-null   float64
#  71  percent_black                                       1288 non-null   float64
#  72  percent_american_indian_alaska_native               1288 non-null   float64
#  73  percent_asian                                       1288 non-null   float64
#  74  percent_native_hawaiian_other_pacific_islander      1288 non-null   float64
#  75  percent_hispanic                                    1288 non-null   float64
#  76  percent_non_hispanic_white                          1288 non-null   float64
#  77  percent_not_proficient_in_english                   1288 non-null   float64
#  78  percent_female                                      1288 non-null   float64
#  79  percent_rural                                       1288 non-null   float64
# dtypes: float64(71), int64(6), object(3)
# memory usage: 815.1+ KB

# %%
final_data = complete_data.dropna(thresh=1260, axis=1)

# %%
final_data.shape
# Out:
# (1288, 80)

# %%
final_data.dropna()
# Out:
#         state      county  population  state_house_blue_perc  density_km  \
# 0     Alabama     Autauga       54571                  22.86      35.436
# 1     Alabama     Baldwin      182265                  22.86      44.261
# 2     Alabama     Calhoun      118572                  22.86      75.572
# 3     Alabama    Chambers       34215                  22.86      22.146
# 4     Alabama     Cullman       80406                  22.86      42.252
# ...       ...         ...         ...                    ...         ...
# 1283  Wyoming     Natrona       78621                  10.00       5.684
# 1284  Wyoming        Park       28702                  10.00       1.596
# 1285  Wyoming    Sheridan       29596                  10.00       4.529
# 1286  Wyoming  Sweetwater       45267                  10.00       1.676
# 1287  Wyoming       Teton       21675                  10.00       2.088
#
#       days_counted  case_sum  death_sum  case_count_28_days  \
# 0               45        67          4                  61
# 1               55       208          5                 168
# 2               51       123          3                  93
# 3               50       311         21                 294
# 4               49        62          0                  58
# ...            ...       ...        ...                 ...
# 1283            49        48          0                  48
# 1284            52         1          0                   1
# 1285            58        16          0                  16
# 1286            45        19          0                  19
# 1287            51        98          1                  96
#
#       death_count_28_days  ...  percent_65_and_over  percent_black  \
# 0                       3  ...            15.562670      19.343177
# 1                       3  ...            20.443350       8.783976
# 2                       3  ...            17.717476      20.850215
# 3                      21  ...            19.521047      39.565670
# 4                       0  ...            18.511062       1.205628
# ...                   ...  ...                  ...            ...
# 1283                    0  ...            15.395311       1.161600
# 1284                    0  ...            23.206247       0.682035
# 1285                    0  ...            20.993616       0.797142
# 1286                    0  ...            12.111217       1.145153
# 1287                    1  ...            15.415277       0.632555
#
#       percent_american_indian_alaska_native  percent_asian  \
# 0                                  0.480207       1.224798
# 1                                  0.772399       1.150343
# 2                                  0.539916       0.964324
# 3                                  0.306411       1.326789
# 4                                  0.645958       0.672323
# ...                                     ...            ...
# 1283                               1.466220       0.827909
# 1284                               0.944619       0.821852
# 1285                               1.366057       0.823603
# 1286                               1.544680       1.010429
# 1287                               0.914172       1.412417
#
#       percent_native_hawaiian_other_pacific_islander  percent_hispanic  \
# 0                                           0.111509          2.965774
# 1                                           0.066966          4.646779
# 2                                           0.110258          3.910673
# 3                                           0.044623          2.561357
# 4                                           0.086287          4.433019
# ...                                              ...               ...
# 1283                                        0.098591          8.581179
# 1284                                        0.057973          5.623380
# 1285                                        0.112460          4.342937
# 1286                                        0.157952         16.083250
# 1287                                        0.151640         14.878038
#
#       percent_non_hispanic_white  percent_not_proficient_in_english  \
# 0                      74.308016                           0.820225
# 1                      83.111337                           0.543517
# 2                      72.024992                           0.991376
# 3                      55.231296                           0.112938
# 4                      91.855421                           0.578012
# ...                          ...                                ...
# 1283                   86.599254                           0.731123
# 1284                   90.915291                           0.627835
# 1285                   91.482817                           0.348727
# 1286                   79.312908                           1.633221
# 1287                   81.504268                           4.314477
#
#       percent_female  percent_rural
# 0          51.448715      42.002162
# 1          51.538377      42.279099
# 2          51.946586      33.696826
# 3          52.125539      49.148034
# 4          50.570456      73.239559
# ...              ...            ...
# 1283       49.617645      14.449304
# 1284       50.194380      44.240383
# 1285       49.793272      35.478775
# 1286       48.544749      10.916313
# 1287       48.403449      46.430920
#
# [1222 rows x 80 columns]

# %%
wrangled_data = final_data.dropna()

# %%
print(wrangled_data.columns)
# Out:
# Index(['state', 'county', 'population', 'state_house_blue_perc', 'density_km',
#        'days_counted', 'case_sum', 'death_sum', 'case_count_28_days',
#        'death_count_28_days', 'confirmed_infection(%_of_pop)',
#        'death_perc(%_of_case)', 'avg_daily_case_increase(%_of_pop)',
#        'case_count_28_days(%_of_pop)', 'death_count_28_days(%_of_case)',
#        'years_of_potential_life_lost_rate', 'percent_fair_or_poor_health',
#        'percent_low_birthweight', 'percent_smokers',
#        'percent_adults_with_obesity', 'food_environment_index',
#        'percent_physically_inactive',
#        'percent_with_access_to_exercise_opportunities',
#        'percent_excessive_drinking',
#        'percent_driving_deaths_with_alcohol_involvement', 'chlamydia_rate',
#        'teen_birth_rate', 'percent_uninsured', 'primary_care_physicians_rate',
#        'dentist_rate', 'mental_health_provider_rate',
#        'preventable_hospitalization_rate', 'percent_with_annual_mammogram',
#        'percent_vaccinated', 'high_school_graduation_rate',
#        'percent_some_college', 'labor_force', 'percent_unemployed',
#        'percent_children_in_poverty', '80th_percentile_income',
#        '20th_percentile_income', 'percent_single_parent_households',
#        'social_association_rate', 'injury_death_rate', 'average_daily_pm2_5',
#        'presence_of_water_violation', 'percent_severe_housing_problems',
#        'severe_housing_cost_burden', 'overcrowding', 'inadequate_facilities',
#        'percent_drive_alone_to_work', 'percent_long_commute_drives_alone',
#        'life_expectancy', 'age_adjusted_death_rate',
#        'percent_frequent_physical_distress',
#        'percent_frequent_mental_distress', 'percent_adults_with_diabetes',
#        'percent_food_insecure', 'percent_limited_access_to_healthy_foods',
#        'percent_insufficient_sleep', 'percent_uninsured_2',
#        'percent_uninsured_3', 'other_primary_care_provider_rate',
#        'median_household_income', 'household_income_white',
#        'segregation_index_2',
#        'average_traffic_volume_per_meter_of_major_roadways',
#        'percent_homeowners', 'percent_severe_housing_cost_burden',
#        'percent_less_than_18_years_of_age', 'percent_65_and_over',
#        'percent_black', 'percent_american_indian_alaska_native',
#        'percent_asian', 'percent_native_hawaiian_other_pacific_islander',
#        'percent_hispanic', 'percent_non_hispanic_white',
#        'percent_not_proficient_in_english', 'percent_female', 'percent_rural'],
#       dtype='object')

# %%
wrangled_data = wrangled_data.drop(['population', 'case_sum', 'death_sum'], axis=1)

# %%
wrangled_data
# Out:
#         state      county  state_house_blue_perc  density_km  days_counted  \
# 0     Alabama     Autauga                  22.86      35.436            45
# 1     Alabama     Baldwin                  22.86      44.261            55
# 2     Alabama     Calhoun                  22.86      75.572            51
# 3     Alabama    Chambers                  22.86      22.146            50
# 4     Alabama     Cullman                  22.86      42.252            49
# ...       ...         ...                    ...         ...           ...
# 1283  Wyoming     Natrona                  10.00       5.684            49
# 1284  Wyoming        Park                  10.00       1.596            52
# 1285  Wyoming    Sheridan                  10.00       4.529            58
# 1286  Wyoming  Sweetwater                  10.00       1.676            45
# 1287  Wyoming       Teton                  10.00       2.088            51
#
#       case_count_28_days  death_count_28_days  confirmed_infection(%_of_pop)  \
# 0                     61                    3                       0.122776
# 1                    168                    3                       0.114120
# 2                     93                    3                       0.103734
# 3                    294                   21                       0.908958
# 4                     58                    0                       0.077109
# ...                  ...                  ...                            ...
# 1283                  48                    0                       0.061052
# 1284                   1                    0                       0.003484
# 1285                  16                    0                       0.054061
# 1286                  19                    0                       0.041973
# 1287                  96                    1                       0.452134
#
#       death_perc(%_of_case)  avg_daily_case_increase(%_of_pop)  ...  \
# 0                  5.970149                           0.002728  ...
# 1                  2.403846                           0.002075  ...
# 2                  2.439024                           0.002034  ...
# 3                  6.752412                           0.018179  ...
# 4                  0.000000                           0.001574  ...
# ...                     ...                                ...  ...
# 1283               0.000000                           0.001246  ...
# 1284               0.000000                           0.000067  ...
# 1285               0.000000                           0.000932  ...
# 1286               0.000000                           0.000933  ...
# 1287               1.020408                           0.008865  ...
#
#       percent_65_and_over  percent_black  \
# 0               15.562670      19.343177
# 1               20.443350       8.783976
# 2               17.717476      20.850215
# 3               19.521047      39.565670
# 4               18.511062       1.205628
# ...                   ...            ...
# 1283            15.395311       1.161600
# 1284            23.206247       0.682035
# 1285            20.993616       0.797142
# 1286            12.111217       1.145153
# 1287            15.415277       0.632555
#
#       percent_american_indian_alaska_native  percent_asian  \
# 0                                  0.480207       1.224798
# 1                                  0.772399       1.150343
# 2                                  0.539916       0.964324
# 3                                  0.306411       1.326789
# 4                                  0.645958       0.672323
# ...                                     ...            ...
# 1283                               1.466220       0.827909
# 1284                               0.944619       0.821852
# 1285                               1.366057       0.823603
# 1286                               1.544680       1.010429
# 1287                               0.914172       1.412417
#
#       percent_native_hawaiian_other_pacific_islander  percent_hispanic  \
# 0                                           0.111509          2.965774
# 1                                           0.066966          4.646779
# 2                                           0.110258          3.910673
# 3                                           0.044623          2.561357
# 4                                           0.086287          4.433019
# ...                                              ...               ...
# 1283                                        0.098591          8.581179
# 1284                                        0.057973          5.623380
# 1285                                        0.112460          4.342937
# 1286                                        0.157952         16.083250
# 1287                                        0.151640         14.878038
#
#       percent_non_hispanic_white  percent_not_proficient_in_english  \
# 0                      74.308016                           0.820225
# 1                      83.111337                           0.543517
# 2                      72.024992                           0.991376
# 3                      55.231296                           0.112938
# 4                      91.855421                           0.578012
# ...                          ...                                ...
# 1283                   86.599254                           0.731123
# 1284                   90.915291                           0.627835
# 1285                   91.482817                           0.348727
# 1286                   79.312908                           1.633221
# 1287                   81.504268                           4.314477
#
#       percent_female  percent_rural
# 0          51.448715      42.002162
# 1          51.538377      42.279099
# 2          51.946586      33.696826
# 3          52.125539      49.148034
# 4          50.570456      73.239559
# ...              ...            ...
# 1283       49.617645      14.449304
# 1284       50.194380      44.240383
# 1285       49.793272      35.478775
# 1286       48.544749      10.916313
# 1287       48.403449      46.430920
#
# [1222 rows x 77 columns]

# %%
wrangled_data.to_csv('./relevant_data/wrangled_data.csv', index=False)

# %% [markdown]
# Maybe more data is better.
