# %%
import pandas as pd
import numpy as np 
import altair as alt

alt.data_transformers.enable('json')
# Out:
# DataTransformerRegistry.enable('json')

# %%
data = pd.read_csv('./relevant_data/wrangled_data.csv')

# %%
data.head(15)
# Out:
#       state    county  density_km  days_counted  case_count_20_days  \
# 0   Alabama   Autauga      35.436            37                  19
# 1   Alabama   Baldwin      44.261            47                  25
# 2   Alabama   Barbour      11.979            27                  29
# 3   Alabama      Bibb      14.215            31                  26
# 4   Alabama    Blount      34.325            36                  15
# 5   Alabama   Bullock       6.766            35                   8
# 6   Alabama    Butler      10.411            36                   8
# 7   Alabama   Calhoun      75.572            43                  38
# 8   Alabama  Chambers      22.146            42                 102
# 9   Alabama  Cherokee      18.123            36                   9
# 10  Alabama   Chilton      24.327            36                  33
# 11  Alabama    Clarke       8.053            29                  24
# 12  Alabama      Clay       8.908            36                  14
# ...

# %%
data.columns
# Out:
# Index(['state', 'county', 'density_km', 'days_counted', 'case_count_20_days',
#        'death_count_20_days', 'confirmed_infection(%_of_pop)',
#        'death_perc(%_of_case)', 'avg_daily_case_increase(%_of_pop)',
#        'case_count_20_days(%_of_pop)', 'death_count_20_days(%_of_case)',
#        'percent_fair_or_poor_health', 'percent_low_birthweight',
#        'percent_smokers', 'percent_adults_with_obesity',
#        'food_environment_index', 'percent_physically_inactive',
#        'percent_with_access_to_exercise_opportunities',
#        'percent_excessive_drinking',
#        'percent_driving_deaths_with_alcohol_involvement', 'teen_birth_rate',
#        'percent_uninsured', 'primary_care_physicians_rate',
#        'primary_care_physicians_ratio', 'mental_health_provider_rate',
#        'mental_health_provider_ratio', 'preventable_hospitalization_rate',
#        'percent_with_annual_mammogram', 'percent_vaccinated',
# ...

# %%
alt.Chart(data).mark_bar().encode(
    alt.X("case_count_20_days(%_of_pop):Q", bin=alt.Bin(extent=[0, 0.5], step=0.005)),
    y='count()',
)
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
state_data = data[data['state'] == 'New York']

# %%
len(state_data)
# Out:
# 56

# %%
state_data.corr(method='pearson')['case_count_20_days(%_of_pop)'][:30]
# Out:
# density_km                                         0.567528
# days_counted                                       0.449352
# case_count_20_days                                 0.686463
# death_count_20_days                                0.368396
# confirmed_infection(%_of_pop)                      0.875541
# death_perc(%_of_case)                              0.149728
# avg_daily_case_increase(%_of_pop)                  0.903551
# case_count_20_days(%_of_pop)                       1.000000
# death_count_20_days(%_of_case)                    -0.162377
# percent_fair_or_poor_health                       -0.010175
# percent_low_birthweight                            0.082847
# percent_smokers                                   -0.537854
# percent_adults_with_obesity                       -0.509094
# food_environment_index                             0.529457
# percent_physically_inactive                       -0.204323
# percent_with_access_to_exercise_opportunities      0.361529
# ...

# %%
state_data.corr(method='pearson')['case_count_20_days(%_of_pop)'][30:]
# Out:
# 80th_percentile_income                                0.740911
# 20th_percentile_income                                0.590973
# income_ratio                                          0.390050
# percent_single_parent_households                     -0.592269
# social_association_rate                              -0.358778
# injury_death_rate                                    -0.294367
# average_daily_pm2_5                                   0.396755
# percent_severe_housing_problems                       0.739165
# severe_housing_cost_burden                            0.719651
# overcrowding                                          0.642318
# inadequate_facilities                                -0.101466
# percent_drive_alone_to_work                          -0.457425
# percent_long_commute_drives_alone                     0.470152
# life_expectancy                                       0.540198
# age_adjusted_death_rate                              -0.500338
# ...
