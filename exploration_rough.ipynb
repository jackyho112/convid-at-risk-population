# %%
import pandas as pd
import numpy as np 
import altair as alt

alt.data_transformers.enable('json')
# Out:
# DataTransformerRegistry.enable('json')

# %%
def retrieve_appregate_data():
    county_infection_data = pd.read_csv('relevant_data/us-counties.csv')
    county_population_data = pd.read_csv('relevant_data/county-population.csv')
    
    county_infection_popu_data = county_infection_data.merge(
        county_population_data, left_on=['county', 'state'], right_on=['county', 'state']
    )
    
    return county_infection_popu_data

# %%
data = retrieve_appregate_data()

# %%
data[data['cases'] == 0]
# Out:
# Empty DataFrame
# Columns: [date, county, state, fips, cases, deaths, population, land_area_km, density_km]
# Index: []

# %%
data
# Out:
#              date     county          state     fips  cases  deaths  \
# 0      2020-01-21  Snohomish     Washington  53061.0      1       0
# 1      2020-01-22  Snohomish     Washington  53061.0      1       0
# 2      2020-01-23  Snohomish     Washington  53061.0      1       0
# 3      2020-01-24  Snohomish     Washington  53061.0      1       0
# 4      2020-01-25  Snohomish     Washington  53061.0      1       0
# ...           ...        ...            ...      ...    ...     ...
# 89495  2020-04-26      Emmet           Iowa  19063.0      1       0
# 89496  2020-04-26  Jefferson       Nebraska  31095.0      1       0
# 89497  2020-04-26     Ransom   North Dakota  38073.0      1       0
# 89498  2020-04-26       Hand   South Dakota  46059.0      1       0
# 89499  2020-04-26    Calhoun  West Virginia  54013.0      1       0
#
#        population  land_area_km  density_km
# 0          822083          5413     151.872
# 1          822083          5413     151.872
# 2          822083          5413     151.872
# 3          822083          5413     151.872
# 4          822083          5413     151.872
# ...           ...           ...         ...
# 89495       10302          1026      10.041
# 89496        7560          1484       5.094
# 89497        5457          2235       2.442
# 89498        3431          3722       0.922
# 89499        7627           728      10.477
#
# [89500 rows x 9 columns]

# %%
def count_days(series):
    time_series = pd.to_datetime(series)
    first_date = time_series.iloc[0]
    last_date = time_series.iloc[-1]
    
    return (last_date - first_date).days

# %%
def group_data(data):
    grouped_data = data.groupby(['state', 'county']).agg(
        population=('population', lambda x: x.iloc[0]),
        days_counted=('date', count_days),
        case_sum=('cases', lambda x: x.iloc[-1]),
        death_sum=('deaths', lambda x: x.iloc[-1])
    )
    
    grouped_data['confirmed_infection_perc'] = grouped_data['case_sum']/grouped_data['population']*100
    grouped_data['death_perc'] = grouped_data['death_sum']/grouped_data['case_sum']*100
    grouped_data['confirmed_infection_perc_avg_daily'] = grouped_data['confirmed_infection_perc']/grouped_data['days_counted']
    grouped_data = grouped_data[(grouped_data['days_counted'] >= 15) & (grouped_data['confirmed_infection_perc_avg_daily'] != float("inf"))]
    
    return grouped_data

# %%
grouped_data = group_data(data)

# %%
grouped_data
# Out:
#                     population  days_counted  case_sum  death_sum  \
# state   county
# Alabama Autauga          54571            33        37          2
#         Baldwin         182265            43       161          3
#         Barbour          27457            23        33          0
#         Bibb             22915            27        38          0
#         Blount           57322            32        34          0
# ...                        ...           ...       ...        ...
# Wyoming Sublette         10368            29         1          0
#         Sweetwater       45267            33        10          0
#         Teton            21675            39        64          1
#         Uinta            21025            24         6          0
#         Washakie          8464            30         4          0
#
#                     confirmed_infection_perc  death_perc  \
# state   county
# Alabama Autauga                     0.067802    5.405405
#         Baldwin                     0.088333    1.863354
#         Barbour                     0.120188    0.000000
#         Bibb                        0.165830    0.000000
#         Blount                      0.059314    0.000000
# ...                                      ...         ...
# Wyoming Sublette                    0.009645    0.000000
#         Sweetwater                  0.022091    0.000000
#         Teton                       0.295271    1.562500
#         Uinta                       0.028537    0.000000
#         Washakie                    0.047259    0.000000
#
#                     confirmed_infection_perc_avg_daily
# state   county
# Alabama Autauga                               0.002055
#         Baldwin                               0.002054
#         Barbour                               0.005226
#         Bibb                                  0.006142
#         Blount                                0.001854
# ...                                                ...
# Wyoming Sublette                              0.000333
#         Sweetwater                            0.000669
#         Teton                                 0.007571
#         Uinta                                 0.001189
#         Washakie                              0.001575
#
# [2581 rows x 7 columns]

# %%
grouped_data.sample(10)
# Out:
#                                population  days_counted  case_sum  death_sum  \
# state          county
# Tennessee      Giles                29485            27         6          0
# North Carolina Vance                44420            34        51          3
# Wisconsin      Door                 27785            27        10          1
# Virginia       Richmond              8908            23        89          0
# Michigan       Sanilac              43114            32        34          4
# Missouri       Cape Girardeau       75674            33        47          1
# Iowa           Kossuth              15543            35         1          0
# Georgia        Lanier               10400            25         8          1
# Louisiana      Iberia               73240            38       243         16
# Texas          Cass                 30012            37        16          2
#
#                                confirmed_infection_perc  death_perc  \
# state          county
# Tennessee      Giles                           0.020349    0.000000
# North Carolina Vance                           0.114813    5.882353
# Wisconsin      Door                            0.035991   10.000000
# Virginia       Richmond                        0.999102    0.000000
# Michigan       Sanilac                         0.078861   11.764706
# Missouri       Cape Girardeau                  0.062109    2.127660
# Iowa           Kossuth                         0.006434    0.000000
# Georgia        Lanier                          0.076923   12.500000
# Louisiana      Iberia                          0.331786    6.584362
# Texas          Cass                            0.053312   12.500000
#
#                                confirmed_infection_perc_avg_daily
# state          county
# Tennessee      Giles                                     0.000754
# North Carolina Vance                                     0.003377
# Wisconsin      Door                                      0.001333
# Virginia       Richmond                                  0.043439
# Michigan       Sanilac                                   0.002464
# Missouri       Cape Girardeau                            0.001882
# Iowa           Kossuth                                   0.000184
# Georgia        Lanier                                    0.003077
# Louisiana      Iberia                                    0.008731
# Texas          Cass                                      0.001441

# %%
county_health = pd.read_csv('relevant_data/us-county-health-rankings-2020.csv')

# %%
county_health = county_health.dropna(subset=['county'])

# %%
county_health
# Out:
#        fips    state      county  num_deaths  \
# 1      1001  Alabama     Autauga       791.0
# 2      1003  Alabama     Baldwin      2967.0
# 3      1005  Alabama     Barbour       472.0
# 4      1007  Alabama        Bibb       471.0
# 5      1009  Alabama      Blount      1085.0
# ...     ...      ...         ...         ...
# 3188  56037  Wyoming  Sweetwater       532.0
# 3189  56039  Wyoming       Teton       109.0
# 3190  56041  Wyoming       Uinta       256.0
# 3191  56043  Wyoming    Washakie       110.0
# 3192  56045  Wyoming      Weston        89.0
#
#       years_of_potential_life_lost_rate  95percent_ci_low  95percent_ci_high  \
# 1                           8128.591190       7283.340731        8973.841649
# 2                           7354.122530       6918.554269        7789.690790
# 3                          10253.573403       8782.217281       11724.929524
# 4                          11977.539484      10344.064842       13611.014126
# 5                          11335.071134      10288.871387       12381.270881
# ...                                 ...               ...                ...
# 3188                        7831.827655       6915.944384        8747.710925
# 3189                        2730.603992       1991.644111        3469.563872
# 3190                        7330.683549       6011.148684        8650.218415
# 3191                        6586.049959       4500.924119        8671.175799
# 3192                        5388.706947       3608.901615        7739.082057
#
#       quartile  ypll_rate_aian  ypll_rate_aian_95percent_ci_low  ...  \
# 1          1.0             NaN                              NaN  ...
# 2          1.0             NaN                              NaN  ...
# 3          2.0             NaN                              NaN  ...
# 4          3.0             NaN                              NaN  ...
# 5          3.0             NaN                              NaN  ...
# ...        ...             ...                              ...  ...
# 3188       4.0             NaN                              NaN  ...
# 3189       1.0             NaN                              NaN  ...
# 3190       3.0             NaN                              NaN  ...
# 3191       2.0             NaN                              NaN  ...
# 3192       1.0             NaN                              NaN  ...
#
#       percent_hispanic  num_non_hispanic_white  percent_non_hispanic_white  \
# 1             2.965774                   41316                   74.308016
# 2             4.646779                  181201                   83.111337
# 3             4.276355                   11356                   45.641252
# 4             2.625000                   16708                   74.589286
# 5             9.571231                   50255                   86.886238
# ...                ...                     ...                         ...
# 3188         16.083250                   34145                   79.312908
# 3189         14.878038                   18812                   81.504268
# 3190          9.236908                   17741                   87.398394
# 3191         14.051997                    6498                   82.409639
# 3192          4.076360                    6267                   89.952634
#
#       num_not_proficient_in_english  percent_not_proficient_in_english  \
# 1                               426                           0.820225
# 2                              1068                           0.543517
# 3                               398                           1.631683
# 4                                57                           0.268210
# 5                               934                           1.724520
# ...                             ...                                ...
# 3188                            669                           1.633221
# 3189                            945                           4.314477
# 3190                            133                           0.696080
# 3191                             25                           0.324886
# 3192                             58                           0.862069
#
#       95percent_ci_low_39  95percent_ci_high_39  percent_female  num_rural  \
# 1                0.347891              1.292558       51.448715    22921.0
# 2                0.347271              0.739763       51.538377    77060.0
# 3                0.824903              2.438462       47.216752    18613.0
# 4                0.000000              0.807504       46.781250    15663.0
# 5                1.198129              2.250911       50.726141    51562.0
# ...                   ...                   ...             ...        ...
# 3188             0.993813              2.272629       48.544749     4782.0
# 3189             2.787340              5.841615       48.403449     9887.0
# 3190             0.000000              1.429709       49.332479     9101.0
# 3191             0.000000              1.376766       49.422955     3068.0
# 3192             0.000000              2.255604       47.050380     3931.0
#
#       percent_rural
# 1         42.002162
# 2         42.279099
# 3         67.789635
# 4         68.352607
# 5         89.951502
# ...             ...
# 3188      10.916313
# 3189      46.430920
# 3190      43.095937
# 3191      35.954529
# 3192      54.536626
#
# [3142 rows x 507 columns]

# %%
county_health.columns
# Out:
# Index(['fips', 'state', 'county', 'num_deaths',
#        'years_of_potential_life_lost_rate', '95percent_ci_low',
#        '95percent_ci_high', 'quartile', 'ypll_rate_aian',
#        'ypll_rate_aian_95percent_ci_low',
#        ...
#        'percent_hispanic', 'num_non_hispanic_white',
#        'percent_non_hispanic_white', 'num_not_proficient_in_english',
#        'percent_not_proficient_in_english', '95percent_ci_low_39',
#        '95percent_ci_high_39', 'percent_female', 'num_rural', 'percent_rural'],
#       dtype='object', length=507)

# %%
excluded_column_words = [
    'aian',
    'asian',
    'black',
    'hispanic',
    'white',
    'quartile',
    'ci_high',
    'ci_low',
    'dentist',
    'unreliabe',
    'alaska',
    'hawaiian',
    'population',
    'grade',
    'firearm',
    'petitioned',
    'fips'
]


filtered_columns = county_health.columns[~county_health.columns.str.contains('|'.join(excluded_column_words))]

# %%
filtered_columns
# Out:
# Index(['fips', 'state', 'county', 'num_deaths',
#        'years_of_potential_life_lost_rate', 'percent_fair_or_poor_health',
#        'average_number_of_physically_unhealthy_days',
#        'average_number_of_mentally_unhealthy_days', 'unreliable',
#        'percent_low_birthweight',
#        ...
#        'percent_homeowners', 'num_households_with_severe_cost_burden',
#        'percent_severe_housing_cost_burden',
#        'percent_less_than_18_years_of_age', 'percent_65_and_over',
#        'num_not_proficient_in_english', 'percent_not_proficient_in_english',
#        'percent_female', 'num_rural', 'percent_rural'],
#       dtype='object', length=112)

# %%
filtered_columns[:100]
# Out:
# Index(['fips', 'state', 'county', 'num_deaths',
#        'years_of_potential_life_lost_rate', 'percent_fair_or_poor_health',
#        'average_number_of_physically_unhealthy_days',
#        'average_number_of_mentally_unhealthy_days', 'unreliable',
#        'percent_low_birthweight', 'percent_smokers',
#        'percent_adults_with_obesity', 'food_environment_index',
#        'percent_physically_inactive',
#        'percent_with_access_to_exercise_opportunities',
#        'percent_excessive_drinking', 'num_alcohol_impaired_driving_deaths',
#        'num_driving_deaths', 'percent_driving_deaths_with_alcohol_involvement',
#        'num_chlamydia_cases', 'chlamydia_rate', 'teen_birth_rate',
#        'num_uninsured', 'percent_uninsured', 'num_primary_care_physicians',
#        'primary_care_physicians_rate', 'primary_care_physicians_ratio',
#        'num_mental_health_providers', 'mental_health_provider_rate',
#        'mental_health_provider_ratio', 'preventable_hospitalization_rate',
#        'percent_with_annual_mammogram', 'percent_vaccinated', 'cohort_size',
#        'high_school_graduation_rate', 'num_some_college',
#        'percent_some_college', 'num_unemployed', 'labor_force',
#        'percent_unemployed', 'percent_children_in_poverty',
#        '80th_percentile_income', '20th_percentile_income', 'income_ratio',
#        'num_single_parent_households', 'num_households',
#        'percent_single_parent_households', 'num_associations',
#        'social_association_rate', 'annual_average_violent_crimes',
#        'violent_crime_rate', 'num_injury_deaths', 'injury_death_rate',
#        'average_daily_pm2_5', 'presence_of_water_violation',
#        'percent_severe_housing_problems', 'severe_housing_cost_burden',
#        'overcrowding', 'inadequate_facilities', 'percent_drive_alone_to_work',
#        'num_workers_who_drive_alone', 'percent_long_commute_drives_alone',
#        'life_expectancy', 'num_deaths_2', 'age_adjusted_death_rate',
#        'num_deaths_3', 'child_mortality_rate', 'num_deaths_4',
#        'infant_mortality_rate', 'percent_frequent_physical_distress',
#        'percent_frequent_mental_distress', 'percent_adults_with_diabetes',
#        'num_hiv_cases', 'hiv_prevalence_rate', 'num_food_insecure',
#        'percent_food_insecure', 'num_limited_access',
#        'percent_limited_access_to_healthy_foods', 'num_drug_overdose_deaths',
#        'drug_overdose_mortality_rate', 'num_motor_vehicle_deaths',
#        'motor_vehicle_mortality_rate', 'percent_insufficient_sleep',
#        'num_uninsured_2', 'percent_uninsured_2', 'num_uninsured_3',
#        'percent_uninsured_3', 'other_primary_care_provider_rate',
#        'other_primary_care_provider_ratio', 'percent_disconnected_youth',
#        'median_household_income', 'percent_enrolled_in_free_or_reduced_lunch',
#        'segregation_index', 'segregation_index_2', 'homicide_rate',
#        'num_deaths_5', 'suicide_rate_age_adjusted', 'crude_rate',
#        'denominator', 'juvenile_arrest_rate'],
#       dtype='object')

# %%
filtered_columns[100:]
# Out:
# Index(['average_traffic_volume_per_meter_of_major_roadways', 'num_homeowners',
#        'percent_homeowners', 'num_households_with_severe_cost_burden',
#        'percent_severe_housing_cost_burden',
#        'percent_less_than_18_years_of_age', 'percent_65_and_over',
#        'num_not_proficient_in_english', 'percent_not_proficient_in_english',
#        'percent_female', 'num_rural', 'percent_rural'],
#       dtype='object')
