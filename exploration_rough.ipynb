# %%
import pandas as pd
import numpy as np 
import altair as alt

alt.data_transformers.enable('json')
# Out:
# DataTransformerRegistry.enable('json')

# %%
def retrieve_appregate_data():
    county_infection_data = pd.read_csv('relevant_data/us-counties.csv')
    county_population_data = pd.read_excel('relevant_data/county-population.xlsx', skiprows=3)
    
    county_population_data = county_population_data[1:].dropna()
    county_population_data['County'] = county_population_data['Unnamed: 0'].str.extract(r'\.(.*?)\ County')
    county_population_data['State'] = county_population_data['Unnamed: 0'].str.extract(r'\, (.*)')
    county_population_data = county_population_data[['County', 'State', 2019]]
    county_population_data.columns = ['County', 'State', '2019 Population']
    county_population_data['2019 Population'] = county_population_data['2019 Population'].astype('int')
    
    county_infection_popu_data = county_infection_data.merge(
        county_population_data, left_on=['county', 'state'], right_on=['County', 'State']
    ).drop(['County', 'State'], axis=1)
    
    return county_infection_popu_data

# %%
data = retrieve_appregate_data()

# %%
data[data['cases'] == 0]
# Out:
# Empty DataFrame
# Columns: [date, county, state, fips, cases, deaths, 2019 Population]
# Index: []

# %%
data
# Out:
#              date     county          state     fips  cases  deaths  \
# 0      2020-01-21  Snohomish     Washington  53061.0      1       0
# 1      2020-01-22  Snohomish     Washington  53061.0      1       0
# 2      2020-01-23  Snohomish     Washington  53061.0      1       0
# 3      2020-01-24  Snohomish     Washington  53061.0      1       0
# 4      2020-01-25  Snohomish     Washington  53061.0      1       0
# ...           ...        ...            ...      ...    ...     ...
# 87461  2020-04-26      Emmet           Iowa  19063.0      1       0
# 87462  2020-04-26  Jefferson       Nebraska  31095.0      1       0
# 87463  2020-04-26     Ransom   North Dakota  38073.0      1       0
# 87464  2020-04-26       Hand   South Dakota  46059.0      1       0
# 87465  2020-04-26    Calhoun  West Virginia  54013.0      1       0
#
#        2019 Population
# 0               822083
# 1               822083
# 2               822083
# 3               822083
# 4               822083
# ...                ...
# 87461             9208
# 87462             7046
# 87463             5218
# 87464             3191
# 87465             7109
#
# [87466 rows x 7 columns]

# %%
def count_days(series):
    time_series = pd.to_datetime(series)
    first_date = time_series.iloc[0]
    last_date = time_series.iloc[-1]
    
    return (last_date - first_date).days

# %%
def group_data(data):
    grouped_data = data.groupby(['state', 'county']).agg(
        population_2019=('2019 Population', lambda x: x.iloc[0]),
        days_counted=('date', count_days),
        case_sum=('cases', lambda x: x.iloc[-1]),
        death_sum=('deaths', lambda x: x.iloc[-1])
    )
    
    grouped_data['confirmed_infection_perc'] = grouped_data['case_sum']/grouped_data['population_2019']*100
    grouped_data['death_perc'] = grouped_data['death_sum']/grouped_data['case_sum']*100
    grouped_data['confirmed_infection_perc_avg_daily'] = grouped_data['confirmed_infection_perc']/grouped_data['days_counted']
    grouped_data = grouped_data[(grouped_data['days_counted'] >= 15) & (grouped_data['confirmed_infection_perc_avg_daily'] != float("inf"))]
    
    return grouped_data

# %%
grouped_data = group_data(data)

# %%
grouped_data
# Out:
#                     population_2019  days_counted  case_sum  death_sum  \
# state   county
# Alabama Autauga               55869            33        37          2
#         Baldwin              223234            43       161          3
#         Barbour               24686            23        33          0
#         Bibb                  22394            27        38          0
#         Blount                57826            32        34          0
# ...                             ...           ...       ...        ...
# Wyoming Sublette               9831            29         1          0
#         Sweetwater            42343            33        10          0
#         Teton                 23464            39        64          1
#         Uinta                 20226            24         6          0
#         Washakie               7805            30         4          0
#
#                     confirmed_infection_perc  death_perc  \
# state   county
# Alabama Autauga                     0.066226    5.405405
#         Baldwin                     0.072122    1.863354
#         Barbour                     0.133679    0.000000
#         Bibb                        0.169688    0.000000
#         Blount                      0.058797    0.000000
# ...                                      ...         ...
# Wyoming Sublette                    0.010172    0.000000
#         Sweetwater                  0.023617    0.000000
#         Teton                       0.272758    1.562500
#         Uinta                       0.029665    0.000000
#         Washakie                    0.051249    0.000000
#
#                     confirmed_infection_perc_avg_daily
# state   county
# Alabama Autauga                               0.002007
#         Baldwin                               0.001677
#         Barbour                               0.005812
#         Bibb                                  0.006285
#         Blount                                0.001837
# ...                                                ...
# Wyoming Sublette                              0.000351
#         Sweetwater                            0.000716
#         Teton                                 0.006994
#         Uinta                                 0.001236
#         Washakie                              0.001708
#
# [2525 rows x 7 columns]

# %%
grouped_data.sample(10)
# Out:
#                         population_2019  days_counted  case_sum  death_sum  \
# state        county
# Iowa         Guthrie              10689            27         6          0
# Missouri     St. Clair             9397            17         2          0
# South Dakota Beadle               18453            47        21          2
# Indiana      Madison             129569            39       394         45
# Oklahoma     Stephens             43143            32        20          1
# Kentucky     Knox                 31145            17         5          0
# New York     Orange              384940            45      8121        203
# South Dakota Brown                38839            35        30          0
# Iowa         Mahaska              22095            31         9          1
# Minnesota    Carver              105089            49        17          0
#
#                         confirmed_infection_perc  death_perc  \
# state        county
# Iowa         Guthrie                    0.056132    0.000000
# Missouri     St. Clair                  0.021283    0.000000
# South Dakota Beadle                     0.113803    9.523810
# Indiana      Madison                    0.304085   11.421320
# Oklahoma     Stephens                   0.046357    5.000000
# Kentucky     Knox                       0.016054    0.000000
# New York     Orange                     2.109679    2.499692
# South Dakota Brown                      0.077242    0.000000
# Iowa         Mahaska                    0.040733   11.111111
# Minnesota    Carver                     0.016177    0.000000
#
#                         confirmed_infection_perc_avg_daily
# state        county
# Iowa         Guthrie                              0.002079
# Missouri     St. Clair                            0.001252
# South Dakota Beadle                               0.002421
# Indiana      Madison                              0.007797
# Oklahoma     Stephens                             0.001449
# Kentucky     Knox                                 0.000944
# New York     Orange                               0.046882
# South Dakota Brown                                0.002207
# Iowa         Mahaska                              0.001314
# Minnesota    Carver                               0.000330

# %%
grouped_data.sort_values(by=['confirmed_infection_perc'], ascending=False).head(10)
# Out:
#                         population_2019  days_counted  case_sum  death_sum  \
# state      county
# Arkansas   Lincoln                13024            41       727          0
# Tennessee  Bledsoe                15064            29       588          0
# New York   Rockland              325789            51     11256        349
# Ohio       Marion                 65093            37      2178          4
# New York   Westchester           967506            53     27664       1054
# Ohio       Pickaway               58457            32      1658          5
# New York   Nassau               1356924            52     34522       1962
# Iowa       Louisa                 11035            23       267          2
# Georgia    Randolph                6778            37       153         19
# New Jersey Passaic               501826            49     11137        426
#
#                         confirmed_infection_perc  death_perc  \
# state      county
# Arkansas   Lincoln                      5.582002    0.000000
# Tennessee  Bledsoe                      3.903346    0.000000
# New York   Rockland                     3.454997    3.100569
# Ohio       Marion                       3.345982    0.183655
# New York   Westchester                  2.859310    3.810006
# Ohio       Pickaway                     2.836273    0.301568
# New York   Nassau                       2.544137    5.683332
# Iowa       Louisa                       2.419574    0.749064
# Georgia    Randolph                     2.257303   12.418301
# New Jersey Passaic                      2.219295    3.825088
#
#                         confirmed_infection_perc_avg_daily
# state      county
# Arkansas   Lincoln                                0.136146
# Tennessee  Bledsoe                                0.134598
# New York   Rockland                               0.067745
# Ohio       Marion                                 0.090432
# New York   Westchester                            0.053949
# Ohio       Pickaway                               0.088634
# New York   Nassau                                 0.048926
# Iowa       Louisa                                 0.105199
# Georgia    Randolph                               0.061008
# New Jersey Passaic                                0.045292

# %%
grouped_data.sort_values(by=['confirmed_infection_perc'], ascending=False).tail(10)
# Out:
#                      population_2019  days_counted  case_sum  death_sum  \
# state        county
# Missouri     Phelps            44573            20         2          0
# Minnesota    Itasca            45130            27         2          0
# Oklahoma     Carter            48111            32         2          0
# Oregon       Crook             24404            23         1          0
# South Dakota Meade             28332            32         1          0
# Wyoming      Park              29194            40         1          0
# Missouri     Polk              32149            19         1          0
# Wisconsin    Wood              72999            41         2          0
# Pennsylvania Warren            39191            32         1          1
# California   Tehama            65084            23         1          0
#
#                      confirmed_infection_perc  death_perc  \
# state        county
# Missouri     Phelps                  0.004487         0.0
# Minnesota    Itasca                  0.004432         0.0
# Oklahoma     Carter                  0.004157         0.0
# Oregon       Crook                   0.004098         0.0
# South Dakota Meade                   0.003530         0.0
# Wyoming      Park                    0.003425         0.0
# Missouri     Polk                    0.003111         0.0
# Wisconsin    Wood                    0.002740         0.0
# Pennsylvania Warren                  0.002552       100.0
# California   Tehama                  0.001536         0.0
#
#                      confirmed_infection_perc_avg_daily
# state        county
# Missouri     Phelps                            0.000224
# Minnesota    Itasca                            0.000164
# Oklahoma     Carter                            0.000130
# Oregon       Crook                             0.000178
# South Dakota Meade                             0.000110
# Wyoming      Park                              0.000086
# Missouri     Polk                              0.000164
# Wisconsin    Wood                              0.000067
# Pennsylvania Warren                            0.000080
# California   Tehama                            0.000067

# %%
grouped_data.sort_values(by=['death_perc'], ascending=False).head(10)
# Out:
#                           population_2019  days_counted  case_sum  death_sum  \
# state          county
# Iowa           Appanoose            12426            31         2          2
# North Dakota   McHenry               5745            31         1          1
# New Mexico     Catron                3527            25         1          1
# Pennsylvania   Warren               39191            32         1          1
# North Dakota   Emmons                3241            21         1          1
# Michigan       Dickinson            25239            30         3          2
# North Carolina Macon                35858            24         2          1
# Oklahoma       Major                 7629            23         2          1
# Wisconsin      Iron                  5687            30         2          1
# Colorado       Crowley               6061            38         2          1
#
#                           confirmed_infection_perc  death_perc  \
# state          county
# Iowa           Appanoose                  0.016095  100.000000
# North Dakota   McHenry                    0.017406  100.000000
# New Mexico     Catron                     0.028353  100.000000
# Pennsylvania   Warren                     0.002552  100.000000
# North Dakota   Emmons                     0.030855  100.000000
# Michigan       Dickinson                  0.011886   66.666667
# North Carolina Macon                      0.005578   50.000000
# Oklahoma       Major                      0.026216   50.000000
# Wisconsin      Iron                       0.035168   50.000000
# Colorado       Crowley                    0.032998   50.000000
#
#                           confirmed_infection_perc_avg_daily
# state          county
# Iowa           Appanoose                            0.000519
# North Dakota   McHenry                              0.000561
# New Mexico     Catron                               0.001134
# Pennsylvania   Warren                               0.000080
# North Dakota   Emmons                               0.001469
# Michigan       Dickinson                            0.000396
# North Carolina Macon                                0.000232
# Oklahoma       Major                                0.001140
# Wisconsin      Iron                                 0.001172
# Colorado       Crowley                              0.000868

# %%
grouped_data.sort_values(by=['death_perc'], ascending=False).tail(10)
# Out:
#                      population_2019  days_counted  case_sum  death_sum  \
# state     county
# Minnesota Traverse              3259            26         2          0
#           Swift                 9266            19         1          0
#           Steele               36649            36        12          0
#           Stearns             161075            45        38          0
#           Sibley               14865            31         1          0
#           Sherburne            97238            34        16          0
#           Roseau               15165            19         1          0
#           Renville             14548            43         3          0
#           Redwood              15170            20         1          0
# Wyoming   Washakie              7805            30         4          0
#
#                      confirmed_infection_perc  death_perc  \
# state     county
# Minnesota Traverse                   0.061369         0.0
#           Swift                      0.010792         0.0
#           Steele                     0.032743         0.0
#           Stearns                    0.023591         0.0
#           Sibley                     0.006727         0.0
#           Sherburne                  0.016454         0.0
#           Roseau                     0.006594         0.0
#           Renville                   0.020621         0.0
#           Redwood                    0.006592         0.0
# Wyoming   Washakie                   0.051249         0.0
#
#                      confirmed_infection_perc_avg_daily
# state     county
# Minnesota Traverse                             0.002360
#           Swift                                0.000568
#           Steele                               0.000910
#           Stearns                              0.000524
#           Sibley                               0.000217
#           Sherburne                            0.000484
#           Roseau                               0.000347
#           Renville                             0.000480
#           Redwood                              0.000330
# Wyoming   Washakie                             0.001708

# %%
grouped_data.sort_values(by=['confirmed_infection_perc_avg_daily'], ascending=False).head(10)
# Out:
#                     population_2019  days_counted  case_sum  death_sum  \
# state     county
# Arkansas  Lincoln             13024            41       727          0
# Tennessee Bledsoe             15064            29       588          0
# Iowa      Louisa              11035            23       267          2
# Minnesota Nobles              21629            16       352          1
# Ohio      Marion              65093            37      2178          4
#           Pickaway            58457            32      1658          5
# Kansas    Seward              21428            19       336          0
# New York  Rockland           325789            51     11256        349
# Georgia   Randolph             6778            37       153         19
# Indiana   Cass                37689            26       586          1
#
#                     confirmed_infection_perc  death_perc  \
# state     county
# Arkansas  Lincoln                   5.582002    0.000000
# Tennessee Bledsoe                   3.903346    0.000000
# Iowa      Louisa                    2.419574    0.749064
# Minnesota Nobles                    1.627445    0.284091
# Ohio      Marion                    3.345982    0.183655
#           Pickaway                  2.836273    0.301568
# Kansas    Seward                    1.568042    0.000000
# New York  Rockland                  3.454997    3.100569
# Georgia   Randolph                  2.257303   12.418301
# Indiana   Cass                      1.554830    0.170648
#
#                     confirmed_infection_perc_avg_daily
# state     county
# Arkansas  Lincoln                             0.136146
# Tennessee Bledsoe                             0.134598
# Iowa      Louisa                              0.105199
# Minnesota Nobles                              0.101715
# Ohio      Marion                              0.090432
#           Pickaway                            0.088634
# Kansas    Seward                              0.082529
# New York  Rockland                            0.067745
# Georgia   Randolph                            0.061008
# Indiana   Cass                                0.059801

# %%
grouped_data.sort_values(by=['confirmed_infection_perc_avg_daily'], ascending=False).tail(10)
# Out:
#                        population_2019  days_counted  case_sum  death_sum  \
# state        county
# Missouri     Polk                32149            19         1          0
# Michigan     Chippewa            37349            34         2          0
# Ohio         Athens              65327            31         3          1
# Oklahoma     Carter              48111            32         2          0
# South Dakota Meade               28332            32         1          0
# Iowa         Carroll             20165            45         1          0
# Wyoming      Park                29194            40         1          0
# Pennsylvania Warren              39191            32         1          1
# Wisconsin    Wood                72999            41         2          0
# California   Tehama              65084            23         1          0
#
#                        confirmed_infection_perc  death_perc  \
# state        county
# Missouri     Polk                      0.003111    0.000000
# Michigan     Chippewa                  0.005355    0.000000
# Ohio         Athens                    0.004592   33.333333
# Oklahoma     Carter                    0.004157    0.000000
# South Dakota Meade                     0.003530    0.000000
# Iowa         Carroll                   0.004959    0.000000
# Wyoming      Park                      0.003425    0.000000
# Pennsylvania Warren                    0.002552  100.000000
# Wisconsin    Wood                      0.002740    0.000000
# California   Tehama                    0.001536    0.000000
#
#                        confirmed_infection_perc_avg_daily
# state        county
# Missouri     Polk                                0.000164
# Michigan     Chippewa                            0.000157
# Ohio         Athens                              0.000148
# Oklahoma     Carter                              0.000130
# South Dakota Meade                               0.000110
# Iowa         Carroll                             0.000110
# Wyoming      Park                                0.000086
# Pennsylvania Warren                              0.000080
# Wisconsin    Wood                                0.000067
# California   Tehama                              0.000067

# %%
county_health = pd.read_csv('relevant_data/us-county-health-rankings-2020.csv')

# %%
county_health = county_health.dropna(subset=['county'])

# %%
county_health
# Out:
#        fips    state      county  num_deaths  \
# 1      1001  Alabama     Autauga       791.0
# 2      1003  Alabama     Baldwin      2967.0
# 3      1005  Alabama     Barbour       472.0
# 4      1007  Alabama        Bibb       471.0
# 5      1009  Alabama      Blount      1085.0
# ...     ...      ...         ...         ...
# 3188  56037  Wyoming  Sweetwater       532.0
# 3189  56039  Wyoming       Teton       109.0
# 3190  56041  Wyoming       Uinta       256.0
# 3191  56043  Wyoming    Washakie       110.0
# 3192  56045  Wyoming      Weston        89.0
#
#       years_of_potential_life_lost_rate  95percent_ci_low  95percent_ci_high  \
# 1                           8128.591190       7283.340731        8973.841649
# 2                           7354.122530       6918.554269        7789.690790
# 3                          10253.573403       8782.217281       11724.929524
# 4                          11977.539484      10344.064842       13611.014126
# 5                          11335.071134      10288.871387       12381.270881
# ...                                 ...               ...                ...
# 3188                        7831.827655       6915.944384        8747.710925
# 3189                        2730.603992       1991.644111        3469.563872
# 3190                        7330.683549       6011.148684        8650.218415
# 3191                        6586.049959       4500.924119        8671.175799
# 3192                        5388.706947       3608.901615        7739.082057
#
#       quartile  ypll_rate_aian  ypll_rate_aian_95percent_ci_low  ...  \
# 1          1.0             NaN                              NaN  ...
# 2          1.0             NaN                              NaN  ...
# 3          2.0             NaN                              NaN  ...
# 4          3.0             NaN                              NaN  ...
# 5          3.0             NaN                              NaN  ...
# ...        ...             ...                              ...  ...
# 3188       4.0             NaN                              NaN  ...
# 3189       1.0             NaN                              NaN  ...
# 3190       3.0             NaN                              NaN  ...
# 3191       2.0             NaN                              NaN  ...
# 3192       1.0             NaN                              NaN  ...
#
#       percent_hispanic  num_non_hispanic_white  percent_non_hispanic_white  \
# 1             2.965774                   41316                   74.308016
# 2             4.646779                  181201                   83.111337
# 3             4.276355                   11356                   45.641252
# 4             2.625000                   16708                   74.589286
# 5             9.571231                   50255                   86.886238
# ...                ...                     ...                         ...
# 3188         16.083250                   34145                   79.312908
# 3189         14.878038                   18812                   81.504268
# 3190          9.236908                   17741                   87.398394
# 3191         14.051997                    6498                   82.409639
# 3192          4.076360                    6267                   89.952634
#
#       num_not_proficient_in_english  percent_not_proficient_in_english  \
# 1                               426                           0.820225
# 2                              1068                           0.543517
# 3                               398                           1.631683
# 4                                57                           0.268210
# 5                               934                           1.724520
# ...                             ...                                ...
# 3188                            669                           1.633221
# 3189                            945                           4.314477
# 3190                            133                           0.696080
# 3191                             25                           0.324886
# 3192                             58                           0.862069
#
#       95percent_ci_low_39  95percent_ci_high_39  percent_female  num_rural  \
# 1                0.347891              1.292558       51.448715    22921.0
# 2                0.347271              0.739763       51.538377    77060.0
# 3                0.824903              2.438462       47.216752    18613.0
# 4                0.000000              0.807504       46.781250    15663.0
# 5                1.198129              2.250911       50.726141    51562.0
# ...                   ...                   ...             ...        ...
# 3188             0.993813              2.272629       48.544749     4782.0
# 3189             2.787340              5.841615       48.403449     9887.0
# 3190             0.000000              1.429709       49.332479     9101.0
# 3191             0.000000              1.376766       49.422955     3068.0
# 3192             0.000000              2.255604       47.050380     3931.0
#
#       percent_rural
# 1         42.002162
# 2         42.279099
# 3         67.789635
# 4         68.352607
# 5         89.951502
# ...             ...
# 3188      10.916313
# 3189      46.430920
# 3190      43.095937
# 3191      35.954529
# 3192      54.536626
#
# [3142 rows x 507 columns]

# %%
county_health.columns[0:40]
# Out:
# Index(['fips', 'state', 'county', 'num_deaths',
#        'years_of_potential_life_lost_rate', '95percent_ci_low',
#        '95percent_ci_high', 'quartile', 'ypll_rate_aian',
#        'ypll_rate_aian_95percent_ci_low', 'ypll_rate_aian_95percent_ci_high',
#        'ypll_rate_asian', 'ypll_rate_asian_95percent_ci_low',
#        'ypll_rate_asian_95percent_ci_high', 'ypll_rate_black',
#        'ypll_rate_black_95percent_ci_low', 'ypll_rate_black_95percent_ci_high',
#        'ypll_rate_hispanic', 'ypll_rate_hispanic_95percent_ci_low',
#        'ypll_rate_hispanic_95percent_ci_high', 'ypll_rate_white',
#        'ypll_rate_white_95percent_ci_low', 'ypll_rate_white_95percent_ci_high',
#        'percent_fair_or_poor_health', '95percent_ci_low_2',
#        '95percent_ci_high_2', 'quartile_2',
#        'average_number_of_physically_unhealthy_days', '95percent_ci_low_3',
#        '95percent_ci_high_3', 'quartile_3',
#        'average_number_of_mentally_unhealthy_days', '95percent_ci_low_4',
#        '95percent_ci_high_4', 'quartile_4', 'unreliable',
#        'percent_low_birthweight', '95percent_ci_low_5', '95percent_ci_high_5',
#        'quartile_5'],
#       dtype='object')
