# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
import ast

# %%
main_request = requests.get("https://en.wikipedia.org/wiki/Political_party_strength_in_U.S._states")
main_page = BeautifulSoup(main_request.text)

# %%
states = main_page.select('.wikitable.sortable tr')[1:]

# %%
state_names = []
house_blue_perc = []

# %%
for state in states:
    rows = state.select('td')
    state_name = rows[0].text.replace("\n", "")
    
    if state_name == 'Nebraska':
        continue
    
    state_names.append(state_name)
    
    party_in_power, party_ratio = rows[3].text.replace("\n", "").split(' ')
    
    party_numbers = list(map(lambda x: int(''.join(list(filter(str.isdigit, x)))), party_ratio.split('–')))
    
    if party_in_power == 'Republican':
        house_blue_perc.append(round(party_numbers[1]/sum(party_numbers)*100, 2))
    else:
        house_blue_perc.append(round(party_numbers[0]/sum(party_numbers)*100, 2))

# %%
df = pd.DataFrame({
    'state': state_names,
    'state_house_blue_perc': house_blue_perc
})

# %%
df
# Out:
#              state  state_house_blue_perc
# 0          Alabama                  22.86
# 1           Alaska                  35.00
# 2          Arizona                  43.33
# 3         Arkansas                  25.71
# 4       California                  72.50
# 5         Colorado                  54.29
# 6      Connecticut                  61.11
# 7         Delaware                  57.14
# 8          Florida                  42.50
# 9          Georgia                  37.50
# 10          Hawaii                  96.00
# 11           Idaho                  20.00
# 12        Illinois                  67.80
# 13         Indiana                  20.00
# 14            Iowa                  36.00
# 15          Kansas                  27.50
# 16        Kentucky                  23.68
# 17       Louisiana                  30.77
# 18           Maine                  60.00
# 19        Maryland                  68.09
# 20   Massachusetts                  85.00
# ...

# %%
df.to_csv('./relevant_data/state_party_line.csv', index=False)
